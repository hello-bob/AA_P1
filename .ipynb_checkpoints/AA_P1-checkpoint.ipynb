# %% [markdown]
# Your model will be evaluated using two metrics: profit @ top-20, and AUC. The reasons for this is to be in line with a more realistic setting. E.g. one can image data scientists in a team arguing to use AUC and optimize for that. However, as seen in the course, for this scenario, we also imagine management arguing that there is not enough budget (in terms of time and money) to contact a lot of people (or hand out a lot of promotions). Hence, they have come up with the following: based on the top-k would-be churners as predicted by your model, sum some proxy of "retained profitability" in case the customer was indeed a churner, or zero otherwise
#
# As a proxy of profitability, the feature average cost min was deemed to be a good value. Based on the size of the test set, k=20 was deemed to be a good choice. Hence, management cares about optimizing this metric
# Note that only about half of the test set is used for the "public" leaderboard. That means that the score you will see on the leaderboard is done using this part of the test only (you don't know which half). Later on through the semester, submissions are frozen and the resuls on the "hidden" part will be revealed
#
# Also, whilst you can definitely try, the goal is not to "win", but to help you reflect on your model's results, see how others are doing, etc.
#
# Objectives:
#
# Some groups prefer to write their final report using Jupyter Notebook, which is fine too, as long as it is readable top-to-bottom
#
# You can use any predictive technique/approach you want, though focus on the whole process: general setup, critical thinking, and the ability to get and validate an outcome
#
# You're free to use unsupervised technique for your data exploration part, too. When you decide to build a black box model, including some interpretability techniques to explain it is a plus
#
# Any other assumptions or insights are thoughts can be included as well: the idea is to take what we've seen in class, get your hands dirty and try out what we've seen
#
# Perform a critical review of the evaluation metric chosen by management. How in line is it with AUC? What would you have picked instead? Were there particular issues with this chosen metric, in your view?

# %%
# !pip install shap

# %%
import pandas as pd
import os
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import numpy as np
import shap

from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.metrics import roc_auc_score, RocCurveDisplay
from sklearn.inspection import permutation_importance

from sklearn.svm import SVC

import xgboost as xgb


pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
# Initialising
TRAIN_SET_FRAC = 0.8
SEED = 42
TARGET_VAR = "target"
DROP_VARS = ['Connect_Date', 'id'] # TBC
KFOLD = 5

# %% [markdown]
# **Loading Data**

# %%
# GitHib urls to fetch data from
url_train = 'https://raw.githubusercontent.com/hello-bob/AA_P1/main/data/train.csv'
url_test = 'https://raw.githubusercontent.com/hello-bob/AA_P1/main/data/test.csv'

# Read train and test data
train_data = pd.read_csv(url_train, sep = ',', skipinitialspace = True, engine = 'python')
train_data = train_data.drop(columns=DROP_VARS)
test_data  = pd.read_csv(url_test, sep = ',', skipinitialspace = True, engine = 'python')

# %% [markdown]
# **Data exploration**

# %%
train_data.head()
# Out:
#   Gender   Age      L_O_S  Dropped_Calls    tariff Handset  Peak_calls_Sum  \
# 0      F  50.0  29.200000            2.0  Play 100   BS210            62.0
# 1      M  25.0  46.533333            1.0   CAT 100  ASAD90           146.0
# 2      F  46.0  38.066667            1.0    CAT 50    WC95           160.0
# 3      F  59.0  27.400000            1.0    CAT 50   BS110            84.0
# 4      F  25.0  21.433333            1.0  Play 300    WC95            14.0
#
#    Peak_mins_Sum  OffPeak_calls_Sum  OffPeak_mins_Sum  Weekend_calls_Sum  \
# 0     153.000000              185.0        438.600001                4.0
# 1     718.800000               98.0        164.700000                4.0
# 2     322.800000                7.0        123.900000                0.0
# 3     317.400001               57.0        161.699999                0.0
# 4     309.600000              326.0        637.800000                6.0
#
#    Weekend_mins_Sum  International_mins_Sum  Nat_call_cost_Sum    AvePeak  \
# 0              29.0              126.002615           2.045727   2.467742
# 1              37.2              251.580636          41.072379   4.923288
# 2               0.0               91.584877          21.575073   2.017500
# 3               0.0               23.998036          20.950771   3.778571
# 4              14.4               87.051515           0.000000  22.114286
#
#    AveOffPeak  AveWeekend  National_calls  National mins  AveNational  \
# 0    2.370811        7.25           251.0     620.600001     2.472510
# 1    1.680612        9.30           248.0     920.700000     3.712500
# 2   17.700000        0.00           167.0     446.700000     2.674850
# 3    2.836842        0.00           141.0     479.100000     3.397872
# 4    1.956442        2.40           346.0     961.800000     2.779769
#
#    All_calls_mins  Dropped_calls_ratio Usage_Band  Mins_charge  \
# 0      746.602616             0.003984        Med    20.600001
# 1     1172.280636             0.002016        Med   320.700000
# 2      538.284877             0.002994     MedLow   146.700000
# 3      503.098036             0.003546     MedLow   179.100000
# 4     1048.851515             0.001445        Med  -838.200000
#
#    call_cost_per_min  actual call cost  Total_call_cost  Total_Cost Tariff_OK  \
# 0           9.930712          2.045727        52.446773  112.386773        OK
# 1          12.807103         41.072380       116.546571  221.546571        OK
# 2          12.226326         17.936021        45.411484  128.811484        OK
# 3          11.624922         20.820235        28.019646  111.419646        OK
# 4           9.403618          0.000000        34.820606  112.760606        OK
#
#    average cost min  Peak ratio  OffPeak ratio  Weekend ratio  \
# 0          0.150531    0.246536       0.706735       0.046729
# 1          0.188988    0.780710       0.178886       0.040404
# 2          0.239300    0.722633       0.277367       0.000000
# 3          0.221467    0.662492       0.337508       0.000000
# 4          0.107509    0.321896       0.663132       0.014972
#
#    Nat-InterNat Ratio high Dropped calls No Usage  target
# 0            0.203034                  F        F       0
# 1            0.273249                  F        F       1
# 2            0.205025                  F        F       0
# 3            0.050090                  F        F       0
# 4            0.090509                  F        F       0

# %%
# Check data types
train_data.info()
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5044 entries, 0 to 5043
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Gender                  5044 non-null   object
#  1   Age                     5044 non-null   float64
#  2   L_O_S                   5044 non-null   float64
#  3   Dropped_Calls           5044 non-null   float64
#  4   tariff                  5044 non-null   object
#  5   Handset                 5044 non-null   object
#  6   Peak_calls_Sum          5044 non-null   float64
#  7   Peak_mins_Sum           5044 non-null   float64
#  8   OffPeak_calls_Sum       5044 non-null   float64
#  9   OffPeak_mins_Sum        5044 non-null   float64
#  10  Weekend_calls_Sum       5044 non-null   float64
#  11  Weekend_mins_Sum        5044 non-null   float64
#  12  International_mins_Sum  5044 non-null   float64
#  13  Nat_call_cost_Sum       5044 non-null   float64
#  14  AvePeak                 5044 non-null   float64
#  15  AveOffPeak              5044 non-null   float64
#  16  AveWeekend              5044 non-null   float64
#  17  National_calls          5044 non-null   float64
#  18  National mins           5044 non-null   float64
#  19  AveNational             5044 non-null   float64
#  20  All_calls_mins          5044 non-null   float64
#  21  Dropped_calls_ratio     5040 non-null   float64
#  22  Usage_Band              5040 non-null   object
#  23  Mins_charge             5044 non-null   float64
#  24  call_cost_per_min       5040 non-null   float64
#  25  actual call cost        5044 non-null   float64
#  26  Total_call_cost         5044 non-null   float64
#  27  Total_Cost              5044 non-null   float64
#  28  Tariff_OK               5044 non-null   object
#  29  average cost min        5044 non-null   float64
#  30  Peak ratio              5044 non-null   float64
#  31  OffPeak ratio           5044 non-null   float64
#  32  Weekend ratio           5044 non-null   float64
#  33  Nat-InterNat Ratio      5044 non-null   float64
#  34  high Dropped calls      5044 non-null   object
#  35  No Usage                5044 non-null   object
#  36  target                  5044 non-null   int64
# dtypes: float64(29), int64(1), object(7)
# memory usage: 1.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1682 entries, 0 to 1681
# Data columns (total 38 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Gender                  1682 non-null   object
#  1   Age                     1682 non-null   float64
#  2   Connect_Date            1682 non-null   object
#  3   L_O_S                   1682 non-null   float64
#  4   Dropped_Calls           1682 non-null   float64
#  5   tariff                  1682 non-null   object
#  6   Handset                 1682 non-null   object
#  7   Peak_calls_Sum          1682 non-null   float64
#  8   Peak_mins_Sum           1682 non-null   float64
#  9   OffPeak_calls_Sum       1682 non-null   float64
#  10  OffPeak_mins_Sum        1682 non-null   float64
#  11  Weekend_calls_Sum       1682 non-null   float64
#  12  Weekend_mins_Sum        1682 non-null   float64
#  13  International_mins_Sum  1682 non-null   float64
#  14  Nat_call_cost_Sum       1682 non-null   float64
#  15  AvePeak                 1682 non-null   float64
#  16  AveOffPeak              1682 non-null   float64
#  17  AveWeekend              1682 non-null   float64
#  18  National_calls          1682 non-null   float64
#  19  National mins           1682 non-null   float64
#  20  AveNational             1682 non-null   float64
#  21  All_calls_mins          1682 non-null   float64
#  22  Dropped_calls_ratio     1681 non-null   float64
#  23  Usage_Band              1681 non-null   object
#  24  Mins_charge             1682 non-null   float64
#  25  call_cost_per_min       1681 non-null   float64
#  26  actual call cost        1682 non-null   float64
#  27  Total_call_cost         1682 non-null   float64
#  28  Total_Cost              1682 non-null   float64
#  29  Tariff_OK               1682 non-null   object
#  30  average cost min        1682 non-null   float64
#  31  Peak ratio              1682 non-null   float64
#  32  OffPeak ratio           1682 non-null   float64
#  33  Weekend ratio           1682 non-null   float64
#  34  Nat-InterNat Ratio      1682 non-null   float64
#  35  high Dropped calls      1682 non-null   object
#  36  No Usage                1682 non-null   object
#  37  id                      1682 non-null   object
# dtypes: float64(29), object(9)
# memory usage: 499.5+ KB

# %%
# Basic descriptives
train_data.describe(include='all')
# Out:
#        Gender          Age        L_O_S  Dropped_Calls   tariff Handset  \
# count    5044  5044.000000  5044.000000    5044.000000     5044    5044
# unique      2          NaN          NaN            NaN        5      11
# top         F          NaN          NaN            NaN  CAT 200     S50
# freq     2597          NaN          NaN            NaN     2246    1175
# mean      NaN    31.384417    33.626890       2.677042      NaN     NaN
# std       NaN    12.767989    14.041931       3.427875      NaN     NaN
# min       NaN    12.000000     9.533333       0.000000      NaN     NaN
# 25%       NaN    22.000000    21.266667       0.000000      NaN     NaN
# 50%       NaN    29.000000    33.583334       1.000000      NaN     NaN
# 75%       NaN    39.000000    45.866667       2.000000      NaN     NaN
# max       NaN    80.000000    58.200000      15.000000      NaN     NaN
#
#         Peak_calls_Sum  Peak_mins_Sum  OffPeak_calls_Sum  OffPeak_mins_Sum  \
# count      5044.000000    5044.000000        5044.000000       5044.000000
# unique             NaN            NaN                NaN               NaN
# top                NaN            NaN                NaN               NaN
# freq               NaN            NaN                NaN               NaN
# mean        239.154441     708.610393         104.080293        312.420299
# std         239.627055     503.964199          97.868704        199.094991
# min           0.000000       0.000000           0.000000          0.000000
# 25%          59.000000     307.800001          28.000000        147.525000
# 50%         161.000000     611.699999          73.000000        293.699999
# 75%         343.000000    1015.950000         156.000000        447.000000
# max        1626.000000    2901.600001         560.000000       1091.099999
#
#         Weekend_calls_Sum  Weekend_mins_Sum  International_mins_Sum  \
# count         5044.000000       5044.000000             5044.000000
# unique                NaN               NaN                     NaN
# top                   NaN               NaN                     NaN
# freq                  NaN               NaN                     NaN
# mean            16.487510         50.139360              170.310248
# std             16.379353         36.051349              142.238289
# min              0.000000          0.000000                0.000000
# 25%              4.000000         22.800000               65.511122
# 50%             12.000000         44.400000              132.281821
# 75%             24.000000         72.000000              236.113750
# max            124.000000        205.000000              977.723297
#
#         Nat_call_cost_Sum      AvePeak   AveOffPeak   AveWeekend  \
# count         5044.000000  5044.000000  5044.000000  5044.000000
# unique                NaN          NaN          NaN          NaN
# top                   NaN          NaN          NaN          NaN
# freq                  NaN          NaN          NaN          NaN
# mean            19.433408     8.677779     8.720703     5.758751
# std             28.179154    33.860203    23.948572     9.950477
# min              0.000000     0.000000     0.000000     0.000000
# 25%              0.000000     1.998552     1.963418     1.882658
# 50%              8.063094     2.915522     2.949500     2.822479
# 75%             29.085798     5.986867     5.779012     5.300000
# max            190.464195  1175.400000   489.600000   149.400000
#
#         National_calls  National mins  AveNational  All_calls_mins  \
# count      5044.000000    5044.000000  5044.000000     5044.000000
# unique             NaN            NaN          NaN             NaN
# top                NaN            NaN          NaN             NaN
# freq               NaN            NaN          NaN             NaN
# mean        359.722244    1071.170052     4.117578     1241.480300
# std         259.621742     543.766236     3.713455      636.746325
# min           0.000000       0.000000     0.000000        0.000000
# 25%         170.000000     665.700000     2.226314      769.666731
# 50%         297.000000     998.099999     2.976979     1141.279249
# 75%         484.000000    1405.650001     4.513459     1613.921676
# max        1939.000000    3423.300000    55.569811     4109.414942
#
#         Dropped_calls_ratio Usage_Band  Mins_charge  call_cost_per_min  \
# count           5040.000000       5040  5044.000000        5040.000000
# unique                  NaN          5          NaN                NaN
# top                     NaN        Med          NaN                NaN
# freq                    NaN       2779          NaN                NaN
# mean               0.007445        NaN    68.572907          10.092345
# std                0.019773        NaN   477.166180           2.105534
# min                0.000000        NaN -1483.200000           2.000000
# 25%                0.000000        NaN  -104.400001           8.578771
# 50%                0.002304        NaN    75.900001           9.513941
# 75%                0.006897        NaN   284.474999          11.749149
# max                0.500000        NaN  2223.300000          21.734694
#
#         actual call cost  Total_call_cost   Total_Cost Tariff_OK  \
# count        5044.000000      5044.000000  5044.000000      5044
# unique               NaN              NaN          NaN         4
# top                  NaN              NaN          NaN        OK
# freq                 NaN              NaN          NaN      5001
# mean           19.289973        73.909497   187.082344       NaN
# std            28.161217        60.377401    82.471189       NaN
# min             0.000000         0.000000    59.940000       NaN
# 25%             0.000000        32.306809   123.926851       NaN
# 50%             7.800333        58.122962   173.505141       NaN
# 75%            28.747465        99.011752   232.132750       NaN
# max           190.464194       463.233885   613.233885       NaN
#
#         average cost min   Peak ratio  OffPeak ratio  Weekend ratio  \
# count        5044.000000  5044.000000    5044.000000    5044.000000
# unique               NaN          NaN            NaN            NaN
# top                  NaN          NaN            NaN            NaN
# freq                 NaN          NaN            NaN            NaN
# mean            0.168484     0.609938       0.327813       0.061456
# std             0.078024     0.223795       0.209852       0.063664
# min             0.048998     0.000000       0.000000       0.000000
# 25%             0.134453     0.467401       0.165634       0.021097
# 50%             0.154474     0.655549       0.286238       0.043909
# 75%             0.179141     0.782501       0.459535       0.080634
# max             1.357564     1.000000       1.000000       0.797546
#
#         Nat-InterNat Ratio high Dropped calls No Usage       target
# count          5044.000000               5044     5044  5044.000000
# unique                 NaN                  2        2          NaN
# top                    NaN                  F        F          NaN
# freq                   NaN               4915     5040          NaN
# mean              0.162820                NaN      NaN     0.147700
# std               0.104220                NaN      NaN     0.354838
# min               0.000000                NaN      NaN     0.000000
# 25%               0.079444                NaN      NaN     0.000000
# 50%               0.158947                NaN      NaN     0.000000
# 75%               0.244624                NaN      NaN     0.000000
# max               2.601223                NaN      NaN     1.000000

# %% [markdown]
# **Data Cleaning**

# %%
# Impute missing data before modelling: Can quantitate and put it on the report since 4/5k samples
# Apply on the test set. Train set is ok.

train_data.isnull().any().sort_values(ascending=False) # Columns with missing values: Dropped_calls_ratio, Usage_Band, call_cost_per_min.
train_data[train_data.isnull().any(axis=1)] # 4 cases, 2 churners

imputer_compiled = ColumnTransformer(
    [("numeric_imputer", SimpleImputer(strategy="median",), ["Dropped_calls_ratio", "call_cost_per_min"]),
     ("cat_imputer", SimpleImputer(strategy="most_frequent"), ["Usage_Band"])]
)

# Imput median for numeric variables first. Because "most_frequent" strategy will impute for both numeric and categorical data
train_data[["Dropped_calls_ratio", "call_cost_per_min", "Usage_Band"]] = imputer_compiled.fit_transform(train_data)
test_data[["Dropped_calls_ratio", "call_cost_per_min", "Usage_Band"]] = imputer_compiled.transform(test_data)

# Correcting dtype
train_data[["Dropped_calls_ratio", "call_cost_per_min"]] = train_data[["Dropped_calls_ratio", "call_cost_per_min"]].astype(float)
test_data[["Dropped_calls_ratio", "call_cost_per_min"]] = test_data[["Dropped_calls_ratio", "call_cost_per_min"]].astype(float)

# %% [markdown]
# **Exploratory**

# %%
# [For report] Pie chart about class inbalance (train set) + Percentage churn in categorical variable

# %%
# [For report] correlation plot
corr = train_data.corr(numeric_only=True)

fig = go.Figure()
fig.add_trace(
    go.Heatmap(
        x = corr.columns,
        y = corr.index,
        z = np.array(corr),
        text=corr.values,
        texttemplate='%{text:.2f}'
    )
)
fig.update_layout(
    autosize=False,
    width=800,
    height=800,
)
fig.show()

# %%
# Print correlations which has >0.7
"""
All_calls_mins highly correlated to National minutes. It's a sum of National minutes + International mins maybe. This may indicate that
majority of calls are within nation. This corresponds to how Nat_call_cost_Sum is highly correlated to actual call cost. Not sure what's the
diff betwen actuall call cost and total call cost. Nat_call_cost_Sum could be an adjustment of actual call cost, correlation 0.999.

Total_call_cost most strongly correlated with International_mins_Sum and Total_Cost. This may suggest that costs are largely driven by 
international calls

Not sure what total calls indicate, maybe it's cost from other telco-related services e.g. broadband, cable tv etc.

Peak_mins_Sum highly correlated with all_calls_mins and national mins. This may make sense since the more minutes of calling, the higher
likelihood of calling during the peak period?

"""
corr_long = train_data.corr(numeric_only=True).melt(ignore_index=False).reset_index(drop=False)
corr_long = corr_long[(corr_long['index'] != corr_long['variable']) & (abs(corr_long['value']) >0.7)]
corr_long.sort_values(by=['index', 'variable'], ascending=True)

# %%
(round((train_data['International_mins_Sum'] + train_data['National mins']),2) == round(train_data['All_calls_mins'], 2)).sum() #almost all
train_data[['All_calls_mins', 'National mins']]

# %%
train_data.select_dtypes('object').columns.to_list()

# %%
# [For report] Correlation between categorical variables, using cramer's V
# Generally, 
from scipy.stats.contingency import association

cat_corr_cols = train_data.select_dtypes('object').columns.to_list()
while len(cat_corr_cols) > 0:
    col = cat_corr_cols.pop(0)
    print(f'Correlation for {col}')
    for other_col in cat_corr_cols:
        contingency_tbl = pd.crosstab(train_data[col], train_data[other_col])
        cramer_V = association(contingency_tbl, method="cramer")
        print(f'Association with {other_col}: {cramer_V}')
    print('\n')

# %%
pd.crosstab(train_data['tariff'], train_data['Usage_Band'])
pd.crosstab(train_data['Gender'], train_data['Handset'])
pd.crosstab(train_data['high Dropped calls'], train_data['Handset'])

# %%
# On the metric by management
train_data.sort_values(by='average cost min', ascending=False).head(20)

# %%
# Identifying outliers via isolation forest
from sklearn.ensemble import IsolationForest

outlier_df = (train_data.select_dtypes(include='number')
              .drop(columns=TARGET_VAR)
              .dropna()
              .copy())

iso_forest = IsolationForest(random_state=SEED, n_jobs=-1, contamination=0.05).fit(outlier_df)

# %%
outlier_df['outlier_score'] = iso_forest.decision_function(outlier_df) # more negative indicates higher outlier-ness

# %%
# https://stats.stackexchange.com/questions/404017/how-to-get-top-features-that-contribute-to-anomalies-in-isolation-forest
"""
Outstanding variables contributing to outlier (to the left of 0 on x axis) are AveOffPeak, average cost min, AveWeekend, AveNational and 
Dropped_calls_ratio. These tend to indicate the higher the values, the more of an outlier they are.
"""

# Create shap values and plot them
shap_values = shap.TreeExplainer(iso_forest).shap_values(outlier_df)
shap.summary_plot(shap_values, outlier_df, plot_type='violin')

# %%
# Average shap per variable Top few: Weekend_calls_sum, nat_call_cost_sum, dropped_calls, average cost min
# a global measure of feature importance (https://shap.readthedocs.io/en/latest/example_notebooks/overviews/An%20introduction%20to%20explainable%20AI%20with%20Shapley%20values.html)
# These values seem low to the values I saw online. 
explainer = shap.Explainer(iso_forest, outlier_df)
shap_values = explainer(outlier_df)
shap.plots.bar(shap_values)

# %%
# 3 of the top 10 outliers are churners. No discernible pattern between churn and non-churn. Propose to keep all and compare 
# between models which are robust against outliers, and those not.
outlier_df[TARGET_VAR] = train_data[TARGET_VAR].copy()
outlier_df.sort_values(by='outlier_score', ascending=True).head(10).sort_values(by='target')
outlier_df.groupby('target').mean()

# %% [markdown]
# **Modelling**

# %%
X = train_data.drop(columns=TARGET_VAR)
y = train_data[TARGET_VAR] 

NUM_VARS = train_data.select_dtypes(include='number').drop(columns=TARGET_VAR).columns
CAT_VARS = train_data.select_dtypes(include='object').columns

X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=1/KFOLD, stratify=y, random_state=SEED)

# %%
print(NUM_VARS)
print(CAT_VARS)
# Out:
# Index(['Age', 'L_O_S', 'Dropped_Calls', 'Peak_calls_Sum', 'Peak_mins_Sum',
#        'OffPeak_calls_Sum', 'OffPeak_mins_Sum', 'Weekend_calls_Sum',
#        'Weekend_mins_Sum', 'International_mins_Sum', 'Nat_call_cost_Sum',
#        'AvePeak', 'AveOffPeak', 'AveWeekend', 'National_calls',
#        'National mins', 'AveNational', 'All_calls_mins', 'Dropped_calls_ratio',
#        'Mins_charge', 'call_cost_per_min', 'actual call cost',
#        'Total_call_cost', 'Total_Cost', 'average cost min', 'Peak ratio',
#        'OffPeak ratio', 'Weekend ratio', 'Nat-InterNat Ratio'],
#       dtype='object')
# Index(['Gender', 'tariff', 'Handset', 'Usage_Band', 'Tariff_OK',
#        'high Dropped calls', 'No Usage'],
#       dtype='object')

# %%
# Define preprocessors for numerical and categorical features
numerical_preprocessor = Pipeline([
    ("scaler", MinMaxScaler(clip=True))
])

categorical_preprocessor = Pipeline([
    ("onehot", OneHotEncoder(drop="if_binary"))
])

# %%
# Combine preprocessors and model
model = Pipeline([
    ("preprocessor", ColumnTransformer([
        ("numerical", numerical_preprocessor, NUM_VARS),
        ("categorical", categorical_preprocessor, CAT_VARS)
    ])),
    ("model", SVC(probability=True, random_state=SEED, max_iter=25000))
])
model
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('scaler',
#                                                                    MinMaxScaler(clip=True))]),
#                                                   Index(['Age', 'L_O_S', 'Dropped_Calls', 'Peak_calls_Sum', 'Peak_mins_Sum',
#        'OffPeak_calls_Sum', 'OffPeak_mins_Sum', 'Weekend_calls_Sum',
#        'Weekend_mins_Sum', 'International_mins_Sum', 'Nat_call_cost_Sum',
#        'AvePeak', 'AveOffPeak', 'Ave...
#        'Total_call_cost', 'Total_Cost', 'average cost min', 'Peak ratio',
#        'OffPeak ratio', 'Weekend ratio', 'Nat-InterNat Ratio'],
#       dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(drop='if_binary'))]),
#                                                   Index(['Gender', 'tariff', 'Handset', 'Usage_Band', 'Tariff_OK',
#        'high Dropped calls', 'No Usage'],
#       dtype='object'))])),
#                 ('model',
#                  SVC(max_iter=25000, probability=True, random_state=42))])

# %%
# %%time
# For SVM

parameters = {'model__kernel':['linear', 'rbf', 'sigmoid'], 
              'model__C':[0.001, 0.01, 0.1, 1, 10, 100, 1000], 
              'model__gamma':[0.001, 0.01, 0.1, 1, 10, 100, 1000],
             'model__class_weight':[None, 'balanced']} # rmb to add the double underscores to allow gridsearch to fit on pipelines
svc_gs_est = GridSearchCV(estimator=model, param_grid=parameters,cv=KFOLD,
                      scoring="roc_auc",n_jobs=-1, refit=True, verbose=10)
svc_gs_est.fit(X_train, y_train)

print("Done")
# Out:
# Fitting 5 folds for each of 294 candidates, totalling 1470 fits
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [CV 3/5; 2/294] START model__C=0.001, model__class_weight=None, model__gamma=0.001, model__kernel=rbf
# [CV 3/5; 2/294] END model__C=0.001, model__class_weight=None, model__gamma=0.001, model__kernel=rbf;, score=0.736 total time=   1.5s
# [CV 4/5; 3/294] START model__C=0.001, model__class_weight=None, model__gamma=0.001, model__kernel=sigmoid
# [CV 4/5; 3/294] END model__C=0.001, model__class_weight=None, model__gamma=0.001, model__kernel=sigmoid;, score=0.798 total time=   1.1s
# [CV 2/5; 5/294] START model__C=0.001, model__class_weight=None, model__gamma=0.01, model__kernel=rbf
# [CV 2/5; 5/294] END model__C=0.001, model__class_weight=None, model__gamma=0.01, model__kernel=rbf;, score=0.770 total time=   1.5s
# [CV 5/5; 6/294] START model__C=0.001, model__class_weight=None, model__gamma=0.01, model__kernel=sigmoid
# [CV 5/5; 6/294] END model__C=0.001, model__class_weight=None, model__gamma=0.01, model__kernel=sigmoid;, score=0.807 total time=   1.2s
# [CV 5/5; 8/294] START model__C=0.001, model__class_weight=None, model__gamma=0.1, model__kernel=rbf
# [CV 5/5; 8/294] END model__C=0.001, model__class_weight=None, model__gamma=0.1, model__kernel=rbf;, score=0.913 total time=   1.7s
# [CV 1/5; 11/294] START model__C=0.001, model__class_weight=None, model__gamma=1, model__kernel=rbf
# [CV 1/5; 11/294] END model__C=0.001, model__class_weight=None, model__gamma=1, model__kernel=rbf;, score=0.901 total time=   1.9s
# [CV 4/5; 12/294] START model__C=0.001, model__class_weight=None, model__gamma=1, model__kernel=sigmoid
# [CV 4/5; 12/294] END model__C=0.001, model__class_weight=None, model__gamma=1, model__kernel=sigmoid;, score=0.495 total time=   1.6s
# [CV 2/5; 14/294] START model__C=0.001, model__class_weight=None, model__gamma=10, model__kernel=rbf
# [CV 2/5; 14/294] END model__C=0.001, model__class_weight=None, model__gamma=10, model__kernel=rbf;, score=0.830 total time=   1.7s
# [CV 3/5; 16/294] START model__C=0.001, model__class_weight=None, model__gamma=100, model__kernel=linear
# [CV 3/5; 16/294] END model__C=0.001, model__class_weight=None, model__gamma=100, model__kernel=linear;, score=0.770 total time=   1.1s
# [CV 5/5; 17/294] START model__C=0.001, model__class_weight=None, model__gamma=100, model__kernel=rbf
# [CV 5/5; 17/294] END model__C=0.001, model__class_weight=None, model__gamma=100, model__kernel=rbf;, score=0.788 total time=   2.4s
# [CV 4/5; 20/294] START model__C=0.001, model__class_weight=None, model__gamma=1000, model__kernel=rbf
# [CV 4/5; 20/294] END model__C=0.001, model__class_weight=None, model__gamma=1000, model__kernel=rbf;, score=0.500 total time=   2.8s
# [CV 5/5; 22/294] START model__C=0.001, model__class_weight=balanced, model__gamma=0.001, model__kernel=linear
# [CV 5/5; 22/294] END model__C=0.001, model__class_weight=balanced, model__gamma=0.001, model__kernel=linear;, score=0.900 total time=   3.7s
# [CV 3/5; 24/294] START model__C=0.001, model__class_weight=balanced, model__gamma=0.001, model__kernel=sigmoid
# [CV 3/5; 24/294] END model__C=0.001, model__class_weight=balanced, model__gamma=0.001, model__kernel=sigmoid;, score=0.849 total time=   4.3s
# [CV 4/5; 25/294] START model__C=0.001, model__class_weight=balanced, model__gamma=0.01, model__kernel=linear
# [CV 4/5; 25/294] END model__C=0.001, model__class_weight=balanced, model__gamma=0.01, model__kernel=linear;, score=0.891 total time=   3.7s
# [CV 2/5; 27/294] START model__C=0.001, model__class_weight=balanced, model__gamma=0.01, model__kernel=sigmoid
# [CV 2/5; 27/294] END model__C=0.001, model__class_weight=balanced, model__gamma=0.01, model__kernel=sigmoid;, score=0.867 total time=   4.3s
# [CV 5/5; 27/294] START model__C=0.001, model__class_weight=balanced, model__gamma=0.01, model__kernel=sigmoid
# [CV 5/5; 27/294] END model__C=0.001, model__class_weight=balanced, model__gamma=0.01, model__kernel=sigmoid;, score=0.899 total time=   4.4s
# [CV 2/5; 30/294] START model__C=0.001, model__class_weight=balanced, model__gamma=0.1, model__kernel=sigmoid
# [CV 2/5; 30/294] END model__C=0.001, model__class_weight=balanced, model__gamma=0.1, model__kernel=sigmoid;, score=0.859 total time=   4.6s
# [CV 1/5; 31/294] START model__C=0.001, model__class_weight=balanced, model__gamma=1, model__kernel=linear
# [CV 1/5; 31/294] END model__C=0.001, model__class_weight=balanced, model__gamma=1, model__kernel=linear;, score=0.854 total time=   3.7s
# [CV 3/5; 32/294] START model__C=0.001, model__class_weight=balanced, model__gamma=1, model__kernel=rbf
# [CV 3/5; 32/294] END model__C=0.001, model__class_weight=balanced, model__gamma=1, model__kernel=rbf;, score=0.867 total time=   6.0s
# [CV 4/5; 34/294] START model__C=0.001, model__class_weight=balanced, model__gamma=10, model__kernel=linear
# [CV 4/5; 34/294] END model__C=0.001, model__class_weight=balanced, model__gamma=10, model__kernel=linear;, score=0.891 total time=   3.8s
# [CV 1/5; 36/294] START model__C=0.001, model__class_weight=balanced, model__gamma=10, model__kernel=sigmoid
# [CV 1/5; 36/294] END model__C=0.001, model__class_weight=balanced, model__gamma=10, model__kernel=sigmoid;, score=0.552 total time=   3.9s
# [CV 5/5; 36/294] START model__C=0.001, model__class_weight=balanced, model__gamma=10, model__kernel=sigmoid
# [CV 5/5; 36/294] END model__C=0.001, model__class_weight=balanced, model__gamma=10, model__kernel=sigmoid;, score=0.430 total time=   4.1s
# [CV 3/5; 38/294] START model__C=0.001, model__class_weight=balanced, model__gamma=100, model__kernel=rbf
# [CV 3/5; 38/294] END model__C=0.001, model__class_weight=balanced, model__gamma=100, model__kernel=rbf;, score=0.804 total time=   6.6s
# [CV 5/5; 40/294] START model__C=0.001, model__class_weight=balanced, model__gamma=1000, model__kernel=linear
# [CV 5/5; 40/294] END model__C=0.001, model__class_weight=balanced, model__gamma=1000, model__kernel=linear;, score=0.900 total time=   3.8s
# [CV 3/5; 42/294] START model__C=0.001, model__class_weight=balanced, model__gamma=1000, model__kernel=sigmoid
# [CV 3/5; 42/294] END model__C=0.001, model__class_weight=balanced, model__gamma=1000, model__kernel=sigmoid;, score=0.500 total time=   3.9s
# [CV 5/5; 43/294] START model__C=0.01, model__class_weight=None, model__gamma=0.001, model__kernel=linear
# [CV 5/5; 43/294] END model__C=0.01, model__class_weight=None, model__gamma=0.001, model__kernel=linear;, score=0.901 total time=   1.3s
# [CV 1/5; 45/294] START model__C=0.01, model__class_weight=None, model__gamma=0.001, model__kernel=sigmoid
# [CV 1/5; 45/294] END model__C=0.01, model__class_weight=None, model__gamma=0.001, model__kernel=sigmoid;, score=0.817 total time=   1.3s
# [CV 5/5; 45/294] START model__C=0.01, model__class_weight=None, model__gamma=0.001, model__kernel=sigmoid
# [CV 5/5; 45/294] END model__C=0.01, model__class_weight=None, model__gamma=0.001, model__kernel=sigmoid;, score=0.808 total time=   1.2s
# [CV 3/5; 47/294] START model__C=0.01, model__class_weight=None, model__gamma=0.01, model__kernel=rbf
# [CV 3/5; 47/294] END model__C=0.01, model__class_weight=None, model__gamma=0.01, model__kernel=rbf;, score=0.794 total time=   1.8s
# [CV 3/5; 49/294] START model__C=0.01, model__class_weight=None, model__gamma=0.1, model__kernel=linear
# [CV 3/5; 49/294] END model__C=0.01, model__class_weight=None, model__gamma=0.1, model__kernel=linear;, score=0.741 total time=   1.2s
# [CV 2/5; 51/294] START model__C=0.01, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid
# [CV 2/5; 51/294] END model__C=0.01, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid;, score=0.795 total time=   1.7s
# [CV 1/5; 52/294] START model__C=0.01, model__class_weight=None, model__gamma=1, model__kernel=linear
# [CV 1/5; 52/294] END model__C=0.01, model__class_weight=None, model__gamma=1, model__kernel=linear;, score=0.884 total time=   1.2s
# [CV 3/5; 53/294] START model__C=0.01, model__class_weight=None, model__gamma=1, model__kernel=rbf
# [CV 3/5; 53/294] END model__C=0.01, model__class_weight=None, model__gamma=1, model__kernel=rbf;, score=0.905 total time=   2.6s
# [CV 4/5; 55/294] START model__C=0.01, model__class_weight=None, model__gamma=10, model__kernel=linear
# [CV 4/5; 55/294] END model__C=0.01, model__class_weight=None, model__gamma=10, model__kernel=linear;, score=0.846 total time=   1.3s
# [CV 1/5; 57/294] START model__C=0.01, model__class_weight=None, model__gamma=10, model__kernel=sigmoid
# [CV 1/5; 57/294] END model__C=0.01, model__class_weight=None, model__gamma=10, model__kernel=sigmoid;, score=0.540 total time=   1.2s
# [CV 4/5; 57/294] START model__C=0.01, model__class_weight=None, model__gamma=10, model__kernel=sigmoid
# [CV 4/5; 57/294] END model__C=0.01, model__class_weight=None, model__gamma=10, model__kernel=sigmoid;, score=0.470 total time=   1.1s
# [CV 2/5; 58/294] START model__C=0.01, model__class_weight=None, model__gamma=100, model__kernel=linear
# [CV 2/5; 58/294] END model__C=0.01, model__class_weight=None, model__gamma=100, model__kernel=linear;, score=0.870 total time=   1.2s
# [CV 5/5; 58/294] START model__C=0.01, model__class_weight=None, model__gamma=100, model__kernel=linear
# [CV 5/5; 58/294] END model__C=0.01, model__class_weight=None, model__gamma=100, model__kernel=linear;, score=0.901 total time=   1.2s
# [CV 1/5; 60/294] START model__C=0.01, model__class_weight=None, model__gamma=100, model__kernel=sigmoid
# [CV 1/5; 60/294] END model__C=0.01, model__class_weight=None, model__gamma=100, model__kernel=sigmoid;, score=0.500 total time=   1.1s
# [CV 4/5; 60/294] START model__C=0.01, model__class_weight=None, model__gamma=100, model__kernel=sigmoid
# [CV 4/5; 60/294] END model__C=0.01, model__class_weight=None, model__gamma=100, model__kernel=sigmoid;, score=0.500 total time=   1.1s
# [CV 2/5; 61/294] START model__C=0.01, model__class_weight=None, model__gamma=1000, model__kernel=linear
# [CV 2/5; 61/294] END model__C=0.01, model__class_weight=None, model__gamma=1000, model__kernel=linear;, score=0.870 total time=   1.2s
# [CV 5/5; 61/294] START model__C=0.01, model__class_weight=None, model__gamma=1000, model__kernel=linear
# [CV 5/5; 61/294] END model__C=0.01, model__class_weight=None, model__gamma=1000, model__kernel=linear;, score=0.901 total time=   1.2s
# [CV 3/5; 62/294] START model__C=0.01, model__class_weight=None, model__gamma=1000, model__kernel=rbf
# [CV 3/5; 62/294] END model__C=0.01, model__class_weight=None, model__gamma=1000, model__kernel=rbf;, score=0.500 total time=   5.3s
# [CV 1/5; 65/294] START model__C=0.01, model__class_weight=balanced, model__gamma=0.001, model__kernel=rbf
# [CV 1/5; 65/294] END model__C=0.01, model__class_weight=balanced, model__gamma=0.001, model__kernel=rbf;, score=0.854 total time=   5.7s
# [CV 5/5; 66/294] START model__C=0.01, model__class_weight=balanced, model__gamma=0.001, model__kernel=sigmoid
# [CV 5/5; 66/294] END model__C=0.01, model__class_weight=balanced, model__gamma=0.001, model__kernel=sigmoid;, score=0.900 total time=   4.4s
# [CV 3/5; 69/294] START model__C=0.01, model__class_weight=balanced, model__gamma=0.01, model__kernel=sigmoid
# [CV 3/5; 69/294] END model__C=0.01, model__class_weight=balanced, model__gamma=0.01, model__kernel=sigmoid;, score=0.849 total time=   4.4s
# [CV 2/5; 70/294] START model__C=0.01, model__class_weight=balanced, model__gamma=0.1, model__kernel=linear
# [CV 2/5; 70/294] END model__C=0.01, model__class_weight=balanced, model__gamma=0.1, model__kernel=linear;, score=0.910 total time=   2.8s
# [CV 4/5; 71/294] START model__C=0.01, model__class_weight=balanced, model__gamma=0.1, model__kernel=rbf
# [CV 4/5; 71/294] END model__C=0.01, model__class_weight=balanced, model__gamma=0.1, model__kernel=rbf;, score=0.896 total time=   6.0s
# [CV 5/5; 73/294] START model__C=0.01, model__class_weight=balanced, model__gamma=1, model__kernel=linear
# [CV 5/5; 73/294] END model__C=0.01, model__class_weight=balanced, model__gamma=1, model__kernel=linear;, score=0.930 total time=   2.9s
# [CV 2/5; 75/294] START model__C=0.01, model__class_weight=balanced, model__gamma=1, model__kernel=sigmoid
# [CV 2/5; 75/294] END model__C=0.01, model__class_weight=balanced, model__gamma=1, model__kernel=sigmoid;, score=0.541 total time=   4.9s
# [CV 1/5; 76/294] START model__C=0.01, model__class_weight=balanced, model__gamma=10, model__kernel=linear
# [CV 1/5; 76/294] END model__C=0.01, model__class_weight=balanced, model__gamma=10, model__kernel=linear;, score=0.899 total time=   3.0s
# [CV 2/5; 77/294] START model__C=0.01, model__class_weight=balanced, model__gamma=10, model__kernel=rbf
# [CV 2/5; 77/294] END model__C=0.01, model__class_weight=balanced, model__gamma=10, model__kernel=rbf;, score=0.894 total time=   5.8s
# [CV 2/5; 79/294] START model__C=0.01, model__class_weight=balanced, model__gamma=100, model__kernel=linear
# [CV 2/5; 79/294] END model__C=0.01, model__class_weight=balanced, model__gamma=100, model__kernel=linear;, score=0.910 total time=   2.8s
# [CV 5/5; 80/294] START model__C=0.01, model__class_weight=balanced, model__gamma=100, model__kernel=rbf
# [CV 5/5; 80/294] END model__C=0.01, model__class_weight=balanced, model__gamma=100, model__kernel=rbf;, score=0.863 total time=   6.7s
# [CV 1/5; 83/294] START model__C=0.01, model__class_weight=balanced, model__gamma=1000, model__kernel=rbf
# [CV 1/5; 83/294] END model__C=0.01, model__class_weight=balanced, model__gamma=1000, model__kernel=rbf;, score=0.506 total time=   5.5s
# [CV 4/5; 84/294] START model__C=0.01, model__class_weight=balanced, model__gamma=1000, model__kernel=sigmoid
# [CV 4/5; 84/294] END model__C=0.01, model__class_weight=balanced, model__gamma=1000, model__kernel=sigmoid;, score=0.500 total time=   3.8s
# [CV 1/5; 88/294] START model__C=0.1, model__class_weight=None, model__gamma=0.01, model__kernel=linear
# [CV 1/5; 88/294] END model__C=0.1, model__class_weight=None, model__gamma=0.01, model__kernel=linear;, score=0.922 total time=   1.2s
# [CV 5/5; 89/294] START model__C=0.1, model__class_weight=None, model__gamma=0.01, model__kernel=rbf
# [CV 5/5; 89/294] END model__C=0.1, model__class_weight=None, model__gamma=0.01, model__kernel=rbf;, score=0.932 total time=   1.9s
# [CV 4/5; 91/294] START model__C=0.1, model__class_weight=None, model__gamma=0.1, model__kernel=linear
# [CV 4/5; 91/294] END model__C=0.1, model__class_weight=None, model__gamma=0.1, model__kernel=linear;, score=0.922 total time=   1.1s
# [CV 2/5; 93/294] START model__C=0.1, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid
# [CV 2/5; 93/294] END model__C=0.1, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid;, score=0.824 total time=   1.7s
# [CV 2/5; 94/294] START model__C=0.1, model__class_weight=None, model__gamma=1, model__kernel=linear
# [CV 2/5; 94/294] END model__C=0.1, model__class_weight=None, model__gamma=1, model__kernel=linear;, score=0.910 total time=   1.2s
# [CV 4/5; 95/294] START model__C=0.1, model__class_weight=None, model__gamma=1, model__kernel=rbf
# [CV 4/5; 95/294] END model__C=0.1, model__class_weight=None, model__gamma=1, model__kernel=rbf;, score=0.928 total time=   2.7s
# [CV 5/5; 97/294] START model__C=0.1, model__class_weight=None, model__gamma=10, model__kernel=linear
# [CV 5/5; 97/294] END model__C=0.1, model__class_weight=None, model__gamma=10, model__kernel=linear;, score=0.916 total time=   1.2s
# [CV 3/5; 99/294] START model__C=0.1, model__class_weight=None, model__gamma=10, model__kernel=sigmoid
# [CV 3/5; 99/294] END model__C=0.1, model__class_weight=None, model__gamma=10, model__kernel=sigmoid;, score=0.494 total time=   1.1s
# [CV 1/5; 100/294] START model__C=0.1, model__class_weight=None, model__gamma=100, model__kernel=linear
# [CV 1/5; 100/294] END model__C=0.1, model__class_weight=None, model__gamma=100, model__kernel=linear;, score=0.922 total time=   1.2s
# [CV 4/5; 100/294] START model__C=0.1, model__class_weight=None, model__gamma=100, model__kernel=linear
# [CV 4/5; 100/294] END model__C=0.1, model__class_weight=None, model__gamma=100, model__kernel=linear;, score=0.922 total time=   1.1s
# [CV 2/5; 101/294] START model__C=0.1, model__class_weight=None, model__gamma=100, model__kernel=rbf
# [CV 2/5; 101/294] END model__C=0.1, model__class_weight=None, model__gamma=100, model__kernel=rbf;, score=0.829 total time=   6.6s
# [CV 5/5; 104/294] START model__C=0.1, model__class_weight=None, model__gamma=1000, model__kernel=rbf
# [CV 5/5; 104/294] END model__C=0.1, model__class_weight=None, model__gamma=1000, model__kernel=rbf;, score=0.504 total time=   5.4s
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# [CV 2/5; 2/294] START model__C=0.001, model__class_weight=None, model__gamma=0.001, model__kernel=rbf
# [CV 2/5; 2/294] END model__C=0.001, model__class_weight=None, model__gamma=0.001, model__kernel=rbf;, score=0.758 total time=   1.5s
# [CV 5/5; 3/294] START model__C=0.001, model__class_weight=None, model__gamma=0.001, model__kernel=sigmoid
# [CV 5/5; 3/294] END model__C=0.001, model__class_weight=None, model__gamma=0.001, model__kernel=sigmoid;, score=0.808 total time=   1.1s
# [CV 3/5; 5/294] START model__C=0.001, model__class_weight=None, model__gamma=0.01, model__kernel=rbf
# [CV 3/5; 5/294] END model__C=0.001, model__class_weight=None, model__gamma=0.01, model__kernel=rbf;, score=0.718 total time=   1.5s
# [CV 1/5; 7/294] START model__C=0.001, model__class_weight=None, model__gamma=0.1, model__kernel=linear
# [CV 1/5; 7/294] END model__C=0.001, model__class_weight=None, model__gamma=0.1, model__kernel=linear;, score=0.902 total time=   1.0s
# [CV 2/5; 8/294] START model__C=0.001, model__class_weight=None, model__gamma=0.1, model__kernel=rbf
# [CV 2/5; 8/294] END model__C=0.001, model__class_weight=None, model__gamma=0.1, model__kernel=rbf;, score=0.899 total time=   1.6s
# [CV 2/5; 10/294] START model__C=0.001, model__class_weight=None, model__gamma=1, model__kernel=linear
# [CV 2/5; 10/294] END model__C=0.001, model__class_weight=None, model__gamma=1, model__kernel=linear;, score=0.816 total time=   1.1s
# [CV 4/5; 11/294] START model__C=0.001, model__class_weight=None, model__gamma=1, model__kernel=rbf
# [CV 4/5; 11/294] END model__C=0.001, model__class_weight=None, model__gamma=1, model__kernel=rbf;, score=0.923 total time=   1.8s
# [CV 5/5; 13/294] START model__C=0.001, model__class_weight=None, model__gamma=10, model__kernel=linear
# [CV 5/5; 13/294] END model__C=0.001, model__class_weight=None, model__gamma=10, model__kernel=linear;, score=0.900 total time=   1.1s
# [CV 2/5; 15/294] START model__C=0.001, model__class_weight=None, model__gamma=10, model__kernel=sigmoid
# [CV 2/5; 15/294] END model__C=0.001, model__class_weight=None, model__gamma=10, model__kernel=sigmoid;, score=0.430 total time=   1.1s
# [CV 1/5; 16/294] START model__C=0.001, model__class_weight=None, model__gamma=100, model__kernel=linear
# [CV 1/5; 16/294] END model__C=0.001, model__class_weight=None, model__gamma=100, model__kernel=linear;, score=0.902 total time=   1.1s
# [CV 4/5; 17/294] START model__C=0.001, model__class_weight=None, model__gamma=100, model__kernel=rbf
# [CV 4/5; 17/294] END model__C=0.001, model__class_weight=None, model__gamma=100, model__kernel=rbf;, score=0.764 total time=   2.4s
# [CV 5/5; 19/294] START model__C=0.001, model__class_weight=None, model__gamma=1000, model__kernel=linear
# [CV 5/5; 19/294] END model__C=0.001, model__class_weight=None, model__gamma=1000, model__kernel=linear;, score=0.900 total time=   1.1s
# [CV 2/5; 21/294] START model__C=0.001, model__class_weight=None, model__gamma=1000, model__kernel=sigmoid
# [CV 2/5; 21/294] END model__C=0.001, model__class_weight=None, model__gamma=1000, model__kernel=sigmoid;, score=0.500 total time=   1.4s
# [CV 5/5; 21/294] START model__C=0.001, model__class_weight=None, model__gamma=1000, model__kernel=sigmoid
# [CV 5/5; 21/294] END model__C=0.001, model__class_weight=None, model__gamma=1000, model__kernel=sigmoid;, score=0.500 total time=   1.1s
# [CV 3/5; 23/294] START model__C=0.001, model__class_weight=balanced, model__gamma=0.001, model__kernel=rbf
# [CV 3/5; 23/294] END model__C=0.001, model__class_weight=balanced, model__gamma=0.001, model__kernel=rbf;, score=0.849 total time=   6.0s
# [CV 1/5; 25/294] START model__C=0.001, model__class_weight=balanced, model__gamma=0.01, model__kernel=linear
# [CV 1/5; 25/294] END model__C=0.001, model__class_weight=balanced, model__gamma=0.01, model__kernel=linear;, score=0.854 total time=   3.8s
# [CV 2/5; 26/294] START model__C=0.001, model__class_weight=balanced, model__gamma=0.01, model__kernel=rbf
# [CV 2/5; 26/294] END model__C=0.001, model__class_weight=balanced, model__gamma=0.01, model__kernel=rbf;, score=0.868 total time=   5.9s
# [CV 3/5; 28/294] START model__C=0.001, model__class_weight=balanced, model__gamma=0.1, model__kernel=linear
# [CV 3/5; 28/294] END model__C=0.001, model__class_weight=balanced, model__gamma=0.1, model__kernel=linear;, score=0.849 total time=   3.7s
# [CV 4/5; 29/294] START model__C=0.001, model__class_weight=balanced, model__gamma=0.1, model__kernel=rbf
# [CV 4/5; 29/294] END model__C=0.001, model__class_weight=balanced, model__gamma=0.1, model__kernel=rbf;, score=0.896 total time=   5.9s
# [CV 5/5; 31/294] START model__C=0.001, model__class_weight=balanced, model__gamma=1, model__kernel=linear
# [CV 5/5; 31/294] END model__C=0.001, model__class_weight=balanced, model__gamma=1, model__kernel=linear;, score=0.900 total time=   3.8s
# [CV 3/5; 33/294] START model__C=0.001, model__class_weight=balanced, model__gamma=1, model__kernel=sigmoid
# [CV 3/5; 33/294] END model__C=0.001, model__class_weight=balanced, model__gamma=1, model__kernel=sigmoid;, score=0.607 total time=   4.9s
# [CV 2/5; 34/294] START model__C=0.001, model__class_weight=balanced, model__gamma=10, model__kernel=linear
# [CV 2/5; 34/294] END model__C=0.001, model__class_weight=balanced, model__gamma=10, model__kernel=linear;, score=0.867 total time=   3.7s
# [CV 4/5; 35/294] START model__C=0.001, model__class_weight=balanced, model__gamma=10, model__kernel=rbf
# [CV 4/5; 35/294] END model__C=0.001, model__class_weight=balanced, model__gamma=10, model__kernel=rbf;, score=0.901 total time=   6.0s
# [CV 5/5; 37/294] START model__C=0.001, model__class_weight=balanced, model__gamma=100, model__kernel=linear
# [CV 5/5; 37/294] END model__C=0.001, model__class_weight=balanced, model__gamma=100, model__kernel=linear;, score=0.900 total time=   3.8s
# [CV 3/5; 39/294] START model__C=0.001, model__class_weight=balanced, model__gamma=100, model__kernel=sigmoid
# [CV 3/5; 39/294] END model__C=0.001, model__class_weight=balanced, model__gamma=100, model__kernel=sigmoid;, score=0.500 total time=   3.8s
# [CV 3/5; 40/294] START model__C=0.001, model__class_weight=balanced, model__gamma=1000, model__kernel=linear
# [CV 3/5; 40/294] END model__C=0.001, model__class_weight=balanced, model__gamma=1000, model__kernel=linear;, score=0.849 total time=   3.8s
# [CV 1/5; 42/294] START model__C=0.001, model__class_weight=balanced, model__gamma=1000, model__kernel=sigmoid
# [CV 1/5; 42/294] END model__C=0.001, model__class_weight=balanced, model__gamma=1000, model__kernel=sigmoid;, score=0.500 total time=   3.9s
# [CV 5/5; 42/294] START model__C=0.001, model__class_weight=balanced, model__gamma=1000, model__kernel=sigmoid
# [CV 5/5; 42/294] END model__C=0.001, model__class_weight=balanced, model__gamma=1000, model__kernel=sigmoid;, score=0.500 total time=   4.0s
# [CV 1/5; 46/294] START model__C=0.01, model__class_weight=None, model__gamma=0.01, model__kernel=linear
# [CV 1/5; 46/294] END model__C=0.01, model__class_weight=None, model__gamma=0.01, model__kernel=linear;, score=0.884 total time=   1.2s
# [CV 4/5; 47/294] START model__C=0.01, model__class_weight=None, model__gamma=0.01, model__kernel=rbf
# [CV 4/5; 47/294] END model__C=0.01, model__class_weight=None, model__gamma=0.01, model__kernel=rbf;, score=0.831 total time=   1.7s
# [CV 5/5; 49/294] START model__C=0.01, model__class_weight=None, model__gamma=0.1, model__kernel=linear
# [CV 5/5; 49/294] END model__C=0.01, model__class_weight=None, model__gamma=0.1, model__kernel=linear;, score=0.901 total time=   1.3s
# [CV 3/5; 51/294] START model__C=0.01, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid
# [CV 3/5; 51/294] END model__C=0.01, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid;, score=0.741 total time=   1.7s
# [CV 4/5; 52/294] START model__C=0.01, model__class_weight=None, model__gamma=1, model__kernel=linear
# [CV 4/5; 52/294] END model__C=0.01, model__class_weight=None, model__gamma=1, model__kernel=linear;, score=0.846 total time=   1.3s
# [CV 1/5; 54/294] START model__C=0.01, model__class_weight=None, model__gamma=1, model__kernel=sigmoid
# [CV 1/5; 54/294] END model__C=0.01, model__class_weight=None, model__gamma=1, model__kernel=sigmoid;, score=0.465 total time=   1.8s
# [CV 5/5; 54/294] START model__C=0.01, model__class_weight=None, model__gamma=1, model__kernel=sigmoid
# [CV 5/5; 54/294] END model__C=0.01, model__class_weight=None, model__gamma=1, model__kernel=sigmoid;, score=0.483 total time=   1.8s
# [CV 5/5; 56/294] START model__C=0.01, model__class_weight=None, model__gamma=10, model__kernel=rbf
# [CV 5/5; 56/294] END model__C=0.01, model__class_weight=None, model__gamma=10, model__kernel=rbf;, score=0.898 total time=   5.0s
# [CV 3/5; 60/294] START model__C=0.01, model__class_weight=None, model__gamma=100, model__kernel=sigmoid
# [CV 3/5; 60/294] END model__C=0.01, model__class_weight=None, model__gamma=100, model__kernel=sigmoid;, score=0.500 total time=   1.2s
# [CV 1/5; 61/294] START model__C=0.01, model__class_weight=None, model__gamma=1000, model__kernel=linear
# [CV 1/5; 61/294] END model__C=0.01, model__class_weight=None, model__gamma=1000, model__kernel=linear;, score=0.884 total time=   1.2s
# [CV 4/5; 61/294] START model__C=0.01, model__class_weight=None, model__gamma=1000, model__kernel=linear
# [CV 4/5; 61/294] END model__C=0.01, model__class_weight=None, model__gamma=1000, model__kernel=linear;, score=0.846 total time=   1.2s
# [CV 2/5; 62/294] START model__C=0.01, model__class_weight=None, model__gamma=1000, model__kernel=rbf
# [CV 2/5; 62/294] END model__C=0.01, model__class_weight=None, model__gamma=1000, model__kernel=rbf;, score=0.502 total time=   5.2s
# [CV 5/5; 64/294] START model__C=0.01, model__class_weight=balanced, model__gamma=0.001, model__kernel=linear
# [CV 5/5; 64/294] END model__C=0.01, model__class_weight=balanced, model__gamma=0.001, model__kernel=linear;, score=0.930 total time=   2.9s
# [CV 3/5; 66/294] START model__C=0.01, model__class_weight=balanced, model__gamma=0.001, model__kernel=sigmoid
# [CV 3/5; 66/294] END model__C=0.01, model__class_weight=balanced, model__gamma=0.001, model__kernel=sigmoid;, score=0.849 total time=   4.4s
# [CV 4/5; 67/294] START model__C=0.01, model__class_weight=balanced, model__gamma=0.01, model__kernel=linear
# [CV 4/5; 67/294] END model__C=0.01, model__class_weight=balanced, model__gamma=0.01, model__kernel=linear;, score=0.911 total time=   2.9s
# [CV 5/5; 68/294] START model__C=0.01, model__class_weight=balanced, model__gamma=0.01, model__kernel=rbf
# [CV 5/5; 68/294] END model__C=0.01, model__class_weight=balanced, model__gamma=0.01, model__kernel=rbf;, score=0.900 total time=   5.9s
# [CV 1/5; 71/294] START model__C=0.01, model__class_weight=balanced, model__gamma=0.1, model__kernel=rbf
# [CV 1/5; 71/294] END model__C=0.01, model__class_weight=balanced, model__gamma=0.1, model__kernel=rbf;, score=0.866 total time=   6.1s
# [CV 4/5; 72/294] START model__C=0.01, model__class_weight=balanced, model__gamma=0.1, model__kernel=sigmoid
# [CV 4/5; 72/294] END model__C=0.01, model__class_weight=balanced, model__gamma=0.1, model__kernel=sigmoid;, score=0.883 total time=   4.7s
# [CV 5/5; 74/294] START model__C=0.01, model__class_weight=balanced, model__gamma=1, model__kernel=rbf
# [CV 5/5; 74/294] END model__C=0.01, model__class_weight=balanced, model__gamma=1, model__kernel=rbf;, score=0.919 total time=   5.8s
# [CV 4/5; 76/294] START model__C=0.01, model__class_weight=balanced, model__gamma=10, model__kernel=linear
# [CV 4/5; 76/294] END model__C=0.01, model__class_weight=balanced, model__gamma=10, model__kernel=linear;, score=0.911 total time=   2.8s
# [CV 5/5; 77/294] START model__C=0.01, model__class_weight=balanced, model__gamma=10, model__kernel=rbf
# [CV 5/5; 77/294] END model__C=0.01, model__class_weight=balanced, model__gamma=10, model__kernel=rbf;, score=0.901 total time=   6.0s
# [CV 1/5; 80/294] START model__C=0.01, model__class_weight=balanced, model__gamma=100, model__kernel=rbf
# [CV 1/5; 80/294] END model__C=0.01, model__class_weight=balanced, model__gamma=100, model__kernel=rbf;, score=0.834 total time=   6.6s
# [CV 1/5; 82/294] START model__C=0.01, model__class_weight=balanced, model__gamma=1000, model__kernel=linear
# [CV 1/5; 82/294] END model__C=0.01, model__class_weight=balanced, model__gamma=1000, model__kernel=linear;, score=0.899 total time=   2.8s
# [CV 2/5; 83/294] START model__C=0.01, model__class_weight=balanced, model__gamma=1000, model__kernel=rbf
# [CV 2/5; 83/294] END model__C=0.01, model__class_weight=balanced, model__gamma=1000, model__kernel=rbf;, score=0.502 total time=   5.4s
# [CV 1/5; 85/294] START model__C=0.1, model__class_weight=None, model__gamma=0.001, model__kernel=linear
# [CV 1/5; 85/294] END model__C=0.1, model__class_weight=None, model__gamma=0.001, model__kernel=linear;, score=0.922 total time=   1.2s
# [CV 2/5; 86/294] START model__C=0.1, model__class_weight=None, model__gamma=0.001, model__kernel=rbf
# [CV 2/5; 86/294] END model__C=0.1, model__class_weight=None, model__gamma=0.001, model__kernel=rbf;, score=0.812 total time=   1.8s
# [CV 3/5; 87/294] START model__C=0.1, model__class_weight=None, model__gamma=0.001, model__kernel=sigmoid
# [CV 3/5; 87/294] END model__C=0.1, model__class_weight=None, model__gamma=0.001, model__kernel=sigmoid;, score=0.715 total time=   1.3s
# [CV 1/5; 89/294] START model__C=0.1, model__class_weight=None, model__gamma=0.01, model__kernel=rbf
# [CV 1/5; 89/294] END model__C=0.1, model__class_weight=None, model__gamma=0.01, model__kernel=rbf;, score=0.898 total time=   2.0s
# [CV 1/5; 91/294] START model__C=0.1, model__class_weight=None, model__gamma=0.1, model__kernel=linear
# [CV 1/5; 91/294] END model__C=0.1, model__class_weight=None, model__gamma=0.1, model__kernel=linear;, score=0.922 total time=   1.3s
# [CV 1/5; 93/294] START model__C=0.1, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid
# [CV 1/5; 93/294] END model__C=0.1, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid;, score=0.808 total time=   1.7s
# [CV 5/5; 93/294] START model__C=0.1, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid
# [CV 5/5; 93/294] END model__C=0.1, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid;, score=0.826 total time=   1.8s
# [CV 3/5; 96/294] START model__C=0.1, model__class_weight=None, model__gamma=1, model__kernel=sigmoid
# [CV 3/5; 96/294] END model__C=0.1, model__class_weight=None, model__gamma=1, model__kernel=sigmoid;, score=0.488 total time=   1.8s
# [CV 2/5; 97/294] START model__C=0.1, model__class_weight=None, model__gamma=10, model__kernel=linear
# [CV 2/5; 97/294] END model__C=0.1, model__class_weight=None, model__gamma=10, model__kernel=linear;, score=0.910 total time=   1.2s
# [CV 3/5; 98/294] START model__C=0.1, model__class_weight=None, model__gamma=10, model__kernel=rbf
# [CV 3/5; 98/294] END model__C=0.1, model__class_weight=None, model__gamma=10, model__kernel=rbf;, score=0.865 total time=   5.5s
# [CV 5/5; 101/294] START model__C=0.1, model__class_weight=None, model__gamma=100, model__kernel=rbf
# [CV 5/5; 101/294] END model__C=0.1, model__class_weight=None, model__gamma=100, model__kernel=rbf;, score=0.865 total time=   6.5s
# [CV 3/5; 105/294] START model__C=0.1, model__class_weight=None, model__gamma=1000, model__kernel=sigmoid
# [CV 3/5; 105/294] END model__C=0.1, model__class_weight=None, model__gamma=1000, model__kernel=sigmoid;, score=0.500 total time=   1.1s
# [CV 1/5; 106/294] START model__C=0.1, model__class_weight=balanced, model__gamma=0.001, model__kernel=linear
# [CV 1/5; 106/294] END model__C=0.1, model__class_weight=balanced, model__gamma=0.001, model__kernel=linear;, score=0.919 total time=   2.0s
# [CV 1/5; 107/294] START model__C=0.1, model__class_weight=balanced, model__gamma=0.001, model__kernel=rbf
# [CV 1/5; 107/294] END model__C=0.1, model__class_weight=balanced, model__gamma=0.001, model__kernel=rbf;, score=0.854 total time=   5.9s
# [CV 1/5; 109/294] START model__C=0.1, model__class_weight=balanced, model__gamma=0.01, model__kernel=linear
# [CV 1/5; 109/294] END model__C=0.1, model__class_weight=balanced, model__gamma=0.01, model__kernel=linear;, score=0.919 total time=   2.0s
# [CV 2/5; 110/294] START model__C=0.1, model__class_weight=balanced, model__gamma=0.01, model__kernel=rbf
# [CV 2/5; 110/294] END model__C=0.1, model__class_weight=balanced, model__gamma=0.01, model__kernel=rbf;, score=0.882 total time=   5.8s
# [CV 5/5; 1/294] START model__C=0.001, model__class_weight=None, model__gamma=0.001, model__kernel=linear
# [CV 5/5; 1/294] END model__C=0.001, model__class_weight=None, model__gamma=0.001, model__kernel=linear;, score=0.900 total time=   1.0s
# [CV 2/5; 3/294] START model__C=0.001, model__class_weight=None, model__gamma=0.001, model__kernel=sigmoid
# [CV 2/5; 3/294] END model__C=0.001, model__class_weight=None, model__gamma=0.001, model__kernel=sigmoid;, score=0.772 total time=   1.1s
# [CV 4/5; 4/294] START model__C=0.001, model__class_weight=None, model__gamma=0.01, model__kernel=linear
# [CV 4/5; 4/294] END model__C=0.001, model__class_weight=None, model__gamma=0.01, model__kernel=linear;, score=0.896 total time=   1.0s
# [CV 5/5; 5/294] START model__C=0.001, model__class_weight=None, model__gamma=0.01, model__kernel=rbf
# [CV 5/5; 5/294] END model__C=0.001, model__class_weight=None, model__gamma=0.01, model__kernel=rbf;, score=0.880 total time=   1.5s
# [CV 1/5; 8/294] START model__C=0.001, model__class_weight=None, model__gamma=0.1, model__kernel=rbf
# [CV 1/5; 8/294] END model__C=0.001, model__class_weight=None, model__gamma=0.1, model__kernel=rbf;, score=0.891 total time=   1.6s
# [CV 4/5; 9/294] START model__C=0.001, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid
# [CV 4/5; 9/294] END model__C=0.001, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid;, score=0.807 total time=   1.4s
# [CV 2/5; 11/294] START model__C=0.001, model__class_weight=None, model__gamma=1, model__kernel=rbf
# [CV 2/5; 11/294] END model__C=0.001, model__class_weight=None, model__gamma=1, model__kernel=rbf;, score=0.909 total time=   1.8s
# [CV 3/5; 13/294] START model__C=0.001, model__class_weight=None, model__gamma=10, model__kernel=linear
# [CV 3/5; 13/294] END model__C=0.001, model__class_weight=None, model__gamma=10, model__kernel=linear;, score=0.770 total time=   1.1s
# [CV 5/5; 14/294] START model__C=0.001, model__class_weight=None, model__gamma=10, model__kernel=rbf
# [CV 5/5; 14/294] END model__C=0.001, model__class_weight=None, model__gamma=10, model__kernel=rbf;, score=0.834 total time=   1.6s
# [CV 5/5; 16/294] START model__C=0.001, model__class_weight=None, model__gamma=100, model__kernel=linear
# [CV 5/5; 16/294] END model__C=0.001, model__class_weight=None, model__gamma=100, model__kernel=linear;, score=0.900 total time=   1.1s
# [CV 3/5; 18/294] START model__C=0.001, model__class_weight=None, model__gamma=100, model__kernel=sigmoid
# [CV 3/5; 18/294] END model__C=0.001, model__class_weight=None, model__gamma=100, model__kernel=sigmoid;, score=0.500 total time=   1.1s
# [CV 1/5; 19/294] START model__C=0.001, model__class_weight=None, model__gamma=1000, model__kernel=linear
# [CV 1/5; 19/294] END model__C=0.001, model__class_weight=None, model__gamma=1000, model__kernel=linear;, score=0.902 total time=   1.1s
# [CV 3/5; 20/294] START model__C=0.001, model__class_weight=None, model__gamma=1000, model__kernel=rbf
# [CV 3/5; 20/294] END model__C=0.001, model__class_weight=None, model__gamma=1000, model__kernel=rbf;, score=0.497 total time=   2.8s
# [CV 4/5; 22/294] START model__C=0.001, model__class_weight=balanced, model__gamma=0.001, model__kernel=linear
# [CV 4/5; 22/294] END model__C=0.001, model__class_weight=balanced, model__gamma=0.001, model__kernel=linear;, score=0.891 total time=   3.7s
# [CV 2/5; 24/294] START model__C=0.001, model__class_weight=balanced, model__gamma=0.001, model__kernel=sigmoid
# [CV 2/5; 24/294] END model__C=0.001, model__class_weight=balanced, model__gamma=0.001, model__kernel=sigmoid;, score=0.867 total time=   4.2s
# [CV 3/5; 25/294] START model__C=0.001, model__class_weight=balanced, model__gamma=0.01, model__kernel=linear
# [CV 3/5; 25/294] END model__C=0.001, model__class_weight=balanced, model__gamma=0.01, model__kernel=linear;, score=0.849 total time=   3.8s
# [CV 1/5; 27/294] START model__C=0.001, model__class_weight=balanced, model__gamma=0.01, model__kernel=sigmoid
# [CV 1/5; 27/294] END model__C=0.001, model__class_weight=balanced, model__gamma=0.01, model__kernel=sigmoid;, score=0.854 total time=   4.4s
# [CV 1/5; 28/294] START model__C=0.001, model__class_weight=balanced, model__gamma=0.1, model__kernel=linear
# [CV 1/5; 28/294] END model__C=0.001, model__class_weight=balanced, model__gamma=0.1, model__kernel=linear;, score=0.854 total time=   3.8s
# [CV 3/5; 29/294] START model__C=0.001, model__class_weight=balanced, model__gamma=0.1, model__kernel=rbf
# [CV 3/5; 29/294] END model__C=0.001, model__class_weight=balanced, model__gamma=0.1, model__kernel=rbf;, score=0.860 total time=   5.8s
# [CV 4/5; 31/294] START model__C=0.001, model__class_weight=balanced, model__gamma=1, model__kernel=linear
# [CV 4/5; 31/294] END model__C=0.001, model__class_weight=balanced, model__gamma=1, model__kernel=linear;, score=0.891 total time=   3.7s
# [CV 1/5; 33/294] START model__C=0.001, model__class_weight=balanced, model__gamma=1, model__kernel=sigmoid
# [CV 1/5; 33/294] END model__C=0.001, model__class_weight=balanced, model__gamma=1, model__kernel=sigmoid;, score=0.586 total time=   4.8s
# [CV 1/5; 34/294] START model__C=0.001, model__class_weight=balanced, model__gamma=10, model__kernel=linear
# [CV 1/5; 34/294] END model__C=0.001, model__class_weight=balanced, model__gamma=10, model__kernel=linear;, score=0.854 total time=   3.7s
# [CV 3/5; 35/294] START model__C=0.001, model__class_weight=balanced, model__gamma=10, model__kernel=rbf
# [CV 3/5; 35/294] END model__C=0.001, model__class_weight=balanced, model__gamma=10, model__kernel=rbf;, score=0.868 total time=   6.0s
# [CV 4/5; 37/294] START model__C=0.001, model__class_weight=balanced, model__gamma=100, model__kernel=linear
# [CV 4/5; 37/294] END model__C=0.001, model__class_weight=balanced, model__gamma=100, model__kernel=linear;, score=0.891 total time=   3.7s
# [CV 2/5; 39/294] START model__C=0.001, model__class_weight=balanced, model__gamma=100, model__kernel=sigmoid
# [CV 2/5; 39/294] END model__C=0.001, model__class_weight=balanced, model__gamma=100, model__kernel=sigmoid;, score=0.500 total time=   3.8s
# [CV 1/5; 40/294] START model__C=0.001, model__class_weight=balanced, model__gamma=1000, model__kernel=linear
# [CV 1/5; 40/294] END model__C=0.001, model__class_weight=balanced, model__gamma=1000, model__kernel=linear;, score=0.854 total time=   3.8s
# [CV 4/5; 41/294] START model__C=0.001, model__class_weight=balanced, model__gamma=1000, model__kernel=rbf
# [CV 4/5; 41/294] END model__C=0.001, model__class_weight=balanced, model__gamma=1000, model__kernel=rbf;, score=0.503 total time=   5.4s
# [CV 2/5; 43/294] START model__C=0.01, model__class_weight=None, model__gamma=0.001, model__kernel=linear
# [CV 2/5; 43/294] END model__C=0.01, model__class_weight=None, model__gamma=0.001, model__kernel=linear;, score=0.870 total time=   1.3s
# [CV 4/5; 44/294] START model__C=0.01, model__class_weight=None, model__gamma=0.001, model__kernel=rbf
# [CV 4/5; 44/294] END model__C=0.01, model__class_weight=None, model__gamma=0.001, model__kernel=rbf;, score=0.809 total time=   1.7s
# [CV 2/5; 46/294] START model__C=0.01, model__class_weight=None, model__gamma=0.01, model__kernel=linear
# [CV 2/5; 46/294] END model__C=0.01, model__class_weight=None, model__gamma=0.01, model__kernel=linear;, score=0.870 total time=   1.2s
# [CV 5/5; 47/294] START model__C=0.01, model__class_weight=None, model__gamma=0.01, model__kernel=rbf
# [CV 5/5; 47/294] END model__C=0.01, model__class_weight=None, model__gamma=0.01, model__kernel=rbf;, score=0.926 total time=   1.7s
# [CV 1/5; 50/294] START model__C=0.01, model__class_weight=None, model__gamma=0.1, model__kernel=rbf
# [CV 1/5; 50/294] END model__C=0.01, model__class_weight=None, model__gamma=0.1, model__kernel=rbf;, score=0.926 total time=   2.1s
# [CV 4/5; 51/294] START model__C=0.01, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid
# [CV 4/5; 51/294] END model__C=0.01, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid;, score=0.840 total time=   1.7s
# [CV 2/5; 53/294] START model__C=0.01, model__class_weight=None, model__gamma=1, model__kernel=rbf
# [CV 2/5; 53/294] END model__C=0.01, model__class_weight=None, model__gamma=1, model__kernel=rbf;, score=0.921 total time=   2.5s
# [CV 3/5; 55/294] START model__C=0.01, model__class_weight=None, model__gamma=10, model__kernel=linear
# [CV 3/5; 55/294] END model__C=0.01, model__class_weight=None, model__gamma=10, model__kernel=linear;, score=0.741 total time=   1.3s
# [CV 2/5; 57/294] START model__C=0.01, model__class_weight=None, model__gamma=10, model__kernel=sigmoid
# [CV 2/5; 57/294] END model__C=0.01, model__class_weight=None, model__gamma=10, model__kernel=sigmoid;, score=0.427 total time=   1.1s
# [CV 5/5; 57/294] START model__C=0.01, model__class_weight=None, model__gamma=10, model__kernel=sigmoid
# [CV 5/5; 57/294] END model__C=0.01, model__class_weight=None, model__gamma=10, model__kernel=sigmoid;, score=0.377 total time=   1.2s
# [CV 3/5; 58/294] START model__C=0.01, model__class_weight=None, model__gamma=100, model__kernel=linear
# [CV 3/5; 58/294] END model__C=0.01, model__class_weight=None, model__gamma=100, model__kernel=linear;, score=0.741 total time=   1.2s
# [CV 1/5; 59/294] START model__C=0.01, model__class_weight=None, model__gamma=100, model__kernel=rbf
# [CV 1/5; 59/294] END model__C=0.01, model__class_weight=None, model__gamma=100, model__kernel=rbf;, score=0.834 total time=   6.2s
# [CV 4/5; 62/294] START model__C=0.01, model__class_weight=None, model__gamma=1000, model__kernel=rbf
# [CV 4/5; 62/294] END model__C=0.01, model__class_weight=None, model__gamma=1000, model__kernel=rbf;, score=0.504 total time=   5.2s
# [CV 3/5; 65/294] START model__C=0.01, model__class_weight=balanced, model__gamma=0.001, model__kernel=rbf
# [CV 3/5; 65/294] END model__C=0.01, model__class_weight=balanced, model__gamma=0.001, model__kernel=rbf;, score=0.849 total time=   5.7s
# [CV 2/5; 67/294] START model__C=0.01, model__class_weight=balanced, model__gamma=0.01, model__kernel=linear
# [CV 2/5; 67/294] END model__C=0.01, model__class_weight=balanced, model__gamma=0.01, model__kernel=linear;, score=0.910 total time=   2.8s
# [CV 3/5; 68/294] START model__C=0.01, model__class_weight=balanced, model__gamma=0.01, model__kernel=rbf
# [CV 3/5; 68/294] END model__C=0.01, model__class_weight=balanced, model__gamma=0.01, model__kernel=rbf;, score=0.850 total time=   5.8s
# [CV 4/5; 70/294] START model__C=0.01, model__class_weight=balanced, model__gamma=0.1, model__kernel=linear
# ...
# [CV 2/5; 123/294] END model__C=0.1, model__class_weight=balanced, model__gamma=100, model__kernel=sigmoid;, score=0.500 total time=   3.8s
# [CV 5/5; 123/294] START model__C=0.1, model__class_weight=balanced, model__gamma=100, model__kernel=sigmoid
# [CV 5/5; 123/294] END model__C=0.1, model__class_weight=balanced, model__gamma=100, model__kernel=sigmoid;, score=0.500 total time=   3.8s
# [CV 3/5; 126/294] START model__C=0.1, model__class_weight=balanced, model__gamma=1000, model__kernel=sigmoid
# [CV 3/5; 126/294] END model__C=0.1, model__class_weight=balanced, model__gamma=1000, model__kernel=sigmoid;, score=0.500 total time=   3.9s
# [CV 2/5; 127/294] START model__C=1, model__class_weight=None, model__gamma=0.001, model__kernel=linear
# [CV 2/5; 127/294] END model__C=1, model__class_weight=None, model__gamma=0.001, model__kernel=linear;, score=0.911 total time=   2.0s
# [CV 2/5; 128/294] START model__C=1, model__class_weight=None, model__gamma=0.001, model__kernel=rbf
# [CV 2/5; 128/294] END model__C=1, model__class_weight=None, model__gamma=0.001, model__kernel=rbf;, score=0.898 total time=   1.9s
# [CV 1/5; 130/294] START model__C=1, model__class_weight=None, model__gamma=0.01, model__kernel=linear
# [CV 1/5; 130/294] END model__C=1, model__class_weight=None, model__gamma=0.01, model__kernel=linear;, score=0.926 total time=   2.1s
# [CV 5/5; 131/294] START model__C=1, model__class_weight=None, model__gamma=0.01, model__kernel=rbf
# [CV 5/5; 131/294] END model__C=1, model__class_weight=None, model__gamma=0.01, model__kernel=rbf;, score=0.937 total time=   2.3s
# [CV 4/5; 133/294] START model__C=1, model__class_weight=None, model__gamma=0.1, model__kernel=linear
# [CV 4/5; 133/294] END model__C=1, model__class_weight=None, model__gamma=0.1, model__kernel=linear;, score=0.921 total time=   2.1s
# [CV 3/5; 135/294] START model__C=1, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid
# [CV 3/5; 135/294] END model__C=1, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid;, score=0.773 total time=   1.3s
# [CV 1/5; 137/294] START model__C=1, model__class_weight=None, model__gamma=1, model__kernel=rbf
# [CV 1/5; 137/294] END model__C=1, model__class_weight=None, model__gamma=1, model__kernel=rbf;, score=0.921 total time=   2.7s
# [CV 4/5; 138/294] START model__C=1, model__class_weight=None, model__gamma=1, model__kernel=sigmoid
# [CV 4/5; 138/294] END model__C=1, model__class_weight=None, model__gamma=1, model__kernel=sigmoid;, score=0.498 total time=   1.7s
# [CV 2/5; 140/294] START model__C=1, model__class_weight=None, model__gamma=10, model__kernel=rbf
# [CV 2/5; 140/294] END model__C=1, model__class_weight=None, model__gamma=10, model__kernel=rbf;, score=0.886 total time=   5.8s
# [CV 4/5; 143/294] START model__C=1, model__class_weight=None, model__gamma=100, model__kernel=rbf
# [CV 4/5; 143/294] END model__C=1, model__class_weight=None, model__gamma=100, model__kernel=rbf;, score=0.849 total time=   6.8s
# [CV 5/5; 146/294] START model__C=1, model__class_weight=None, model__gamma=1000, model__kernel=rbf
# [CV 5/5; 146/294] END model__C=1, model__class_weight=None, model__gamma=1000, model__kernel=rbf;, score=0.504 total time=   5.8s
# [CV 1/5; 150/294] START model__C=1, model__class_weight=balanced, model__gamma=0.001, model__kernel=sigmoid
# [CV 1/5; 150/294] END model__C=1, model__class_weight=balanced, model__gamma=0.001, model__kernel=sigmoid;, score=0.854 total time=   4.3s
# [CV 4/5; 150/294] START model__C=1, model__class_weight=balanced, model__gamma=0.001, model__kernel=sigmoid
# [CV 4/5; 150/294] END model__C=1, model__class_weight=balanced, model__gamma=0.001, model__kernel=sigmoid;, score=0.891 total time=   4.3s
# [CV 2/5; 153/294] START model__C=1, model__class_weight=balanced, model__gamma=0.01, model__kernel=sigmoid
# [CV 2/5; 153/294] END model__C=1, model__class_weight=balanced, model__gamma=0.01, model__kernel=sigmoid;, score=0.910 total time=   3.3s
# [CV 5/5; 154/294] START model__C=1, model__class_weight=balanced, model__gamma=0.1, model__kernel=linear
# [CV 5/5; 154/294] END model__C=1, model__class_weight=balanced, model__gamma=0.1, model__kernel=linear;, score=0.934 total time=   2.6s
# [CV 2/5; 156/294] START model__C=1, model__class_weight=balanced, model__gamma=0.1, model__kernel=sigmoid
# [CV 2/5; 156/294] END model__C=1, model__class_weight=balanced, model__gamma=0.1, model__kernel=sigmoid;, score=0.863 total time=   2.5s
# [CV 5/5; 157/294] START model__C=1, model__class_weight=balanced, model__gamma=1, model__kernel=linear
# [CV 5/5; 157/294] END model__C=1, model__class_weight=balanced, model__gamma=1, model__kernel=linear;, score=0.934 total time=   2.6s
# [CV 3/5; 159/294] START model__C=1, model__class_weight=balanced, model__gamma=1, model__kernel=sigmoid
# [CV 3/5; 159/294] END model__C=1, model__class_weight=balanced, model__gamma=1, model__kernel=sigmoid;, score=0.490 total time=   3.9s
# [CV 2/5; 161/294] START model__C=1, model__class_weight=balanced, model__gamma=10, model__kernel=rbf
# [CV 2/5; 161/294] END model__C=1, model__class_weight=balanced, model__gamma=10, model__kernel=rbf;, score=0.885 total time=   6.5s
# [CV 3/5; 163/294] START model__C=1, model__class_weight=balanced, model__gamma=100, model__kernel=linear
# [CV 3/5; 163/294] END model__C=1, model__class_weight=balanced, model__gamma=100, model__kernel=linear;, score=0.918 total time=   2.5s
# [CV 4/5; 164/294] START model__C=1, model__class_weight=balanced, model__gamma=100, model__kernel=rbf
# [CV 4/5; 164/294] END model__C=1, model__class_weight=balanced, model__gamma=100, model__kernel=rbf;, score=0.849 total time=   7.2s
# [CV 1/5; 167/294] START model__C=1, model__class_weight=balanced, model__gamma=1000, model__kernel=rbf
# [CV 1/5; 167/294] END model__C=1, model__class_weight=balanced, model__gamma=1000, model__kernel=rbf;, score=0.507 total time=   6.1s
# [CV 4/5; 168/294] START model__C=1, model__class_weight=balanced, model__gamma=1000, model__kernel=sigmoid
# [CV 4/5; 168/294] END model__C=1, model__class_weight=balanced, model__gamma=1000, model__kernel=sigmoid;, score=0.500 total time=   3.8s
# [CV 1/5; 171/294] START model__C=10, model__class_weight=None, model__gamma=0.001, model__kernel=sigmoid
# [CV 1/5; 171/294] END model__C=10, model__class_weight=None, model__gamma=0.001, model__kernel=sigmoid;, score=0.879 total time=   1.4s
# [CV 5/5; 171/294] START model__C=10, model__class_weight=None, model__gamma=0.001, model__kernel=sigmoid
# [CV 5/5; 171/294] END model__C=10, model__class_weight=None, model__gamma=0.001, model__kernel=sigmoid;, score=0.912 total time=   1.4s
# [CV 3/5; 173/294] START model__C=10, model__class_weight=None, model__gamma=0.01, model__kernel=rbf
# [CV 3/5; 173/294] END model__C=10, model__class_weight=None, model__gamma=0.01, model__kernel=rbf;, score=0.900 total time=   1.8s
# [CV 4/5; 174/294] START model__C=10, model__class_weight=None, model__gamma=0.01, model__kernel=sigmoid
# [CV 4/5; 174/294] END model__C=10, model__class_weight=None, model__gamma=0.01, model__kernel=sigmoid;, score=0.908 total time=   1.9s
# [CV 2/5; 176/294] START model__C=10, model__class_weight=None, model__gamma=0.1, model__kernel=rbf
# [CV 2/5; 176/294] END model__C=10, model__class_weight=None, model__gamma=0.1, model__kernel=rbf;, score=0.927 total time=   1.6s
# [CV 1/5; 177/294] START model__C=10, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid
# [CV 1/5; 177/294] END model__C=10, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid;, score=0.774 total time=   1.0s
# [CV 2/5; 178/294] START model__C=10, model__class_weight=None, model__gamma=1, model__kernel=linear
# [CV 2/5; 178/294] END model__C=10, model__class_weight=None, model__gamma=1, model__kernel=linear;, score=0.908 total time=   2.6s
# [CV 4/5; 179/294] START model__C=10, model__class_weight=None, model__gamma=1, model__kernel=rbf
# [CV 4/5; 179/294] END model__C=10, model__class_weight=None, model__gamma=1, model__kernel=rbf;, score=0.902 total time=   2.5s
# [CV 3/5; 182/294] START model__C=10, model__class_weight=None, model__gamma=10, model__kernel=rbf
# [CV 3/5; 182/294] END model__C=10, model__class_weight=None, model__gamma=10, model__kernel=rbf;, score=0.853 total time=   6.3s
# [CV 1/5; 185/294] START model__C=10, model__class_weight=None, model__gamma=100, model__kernel=rbf
# [CV 1/5; 185/294] END model__C=10, model__class_weight=None, model__gamma=100, model__kernel=rbf;, score=0.841 total time=   7.4s
# [CV 2/5; 188/294] START model__C=10, model__class_weight=None, model__gamma=1000, model__kernel=rbf
# [CV 2/5; 188/294] END model__C=10, model__class_weight=None, model__gamma=1000, model__kernel=rbf;, score=0.502 total time=   6.1s
# [CV 5/5; 190/294] START model__C=10, model__class_weight=balanced, model__gamma=0.001, model__kernel=linear
# [CV 5/5; 190/294] END model__C=10, model__class_weight=balanced, model__gamma=0.001, model__kernel=linear;, score=0.926 total time=   2.7s
# [CV 2/5; 192/294] START model__C=10, model__class_weight=balanced, model__gamma=0.001, model__kernel=sigmoid
# [CV 2/5; 192/294] END model__C=10, model__class_weight=balanced, model__gamma=0.001, model__kernel=sigmoid;, score=0.910 total time=   3.5s
# [CV 1/5; 194/294] START model__C=10, model__class_weight=balanced, model__gamma=0.01, model__kernel=rbf
# [CV 1/5; 194/294] END model__C=10, model__class_weight=balanced, model__gamma=0.01, model__kernel=rbf;, score=0.930 total time=   2.6s
# [CV 3/5; 195/294] START model__C=10, model__class_weight=balanced, model__gamma=0.01, model__kernel=sigmoid
# [CV 3/5; 195/294] END model__C=10, model__class_weight=balanced, model__gamma=0.01, model__kernel=sigmoid;, score=0.908 total time=   2.3s
# [CV 1/5; 197/294] START model__C=10, model__class_weight=balanced, model__gamma=0.1, model__kernel=rbf
# [CV 1/5; 197/294] END model__C=10, model__class_weight=balanced, model__gamma=0.1, model__kernel=rbf;, score=0.938 total time=   2.1s
# [CV 2/5; 198/294] START model__C=10, model__class_weight=balanced, model__gamma=0.1, model__kernel=sigmoid
# [CV 2/5; 198/294] END model__C=10, model__class_weight=balanced, model__gamma=0.1, model__kernel=sigmoid;, score=0.819 total time=   1.7s
# [CV 4/5; 199/294] START model__C=10, model__class_weight=balanced, model__gamma=1, model__kernel=linear
# [CV 4/5; 199/294] END model__C=10, model__class_weight=balanced, model__gamma=1, model__kernel=linear;, score=0.935 total time=   3.1s
# [CV 1/5; 202/294] START model__C=10, model__class_weight=balanced, model__gamma=10, model__kernel=linear
# [CV 1/5; 202/294] END model__C=10, model__class_weight=balanced, model__gamma=10, model__kernel=linear;, score=0.935 total time=   3.0s
# [CV 3/5; 203/294] START model__C=10, model__class_weight=balanced, model__gamma=10, model__kernel=rbf
# [CV 3/5; 203/294] END model__C=10, model__class_weight=balanced, model__gamma=10, model__kernel=rbf;, score=0.853 total time=   6.3s
# [CV 3/5; 205/294] START model__C=10, model__class_weight=balanced, model__gamma=100, model__kernel=linear
# [CV 3/5; 205/294] END model__C=10, model__class_weight=balanced, model__gamma=100, model__kernel=linear;, score=0.916 total time=   3.1s
# [CV 4/5; 206/294] START model__C=10, model__class_weight=balanced, model__gamma=100, model__kernel=rbf
# [CV 4/5; 206/294] END model__C=10, model__class_weight=balanced, model__gamma=100, model__kernel=rbf;, score=0.849 total time=   7.4s
# [CV 2/5; 209/294] START model__C=10, model__class_weight=balanced, model__gamma=1000, model__kernel=rbf
# [CV 2/5; 209/294] END model__C=10, model__class_weight=balanced, model__gamma=1000, model__kernel=rbf;, score=0.502 total time=   6.2s
# [CV 5/5; 210/294] START model__C=10, model__class_weight=balanced, model__gamma=1000, model__kernel=sigmoid
# [CV 5/5; 210/294] END model__C=10, model__class_weight=balanced, model__gamma=1000, model__kernel=sigmoid;, score=0.500 total time=   3.7s
# [CV 4/5; 212/294] START model__C=100, model__class_weight=None, model__gamma=0.001, model__kernel=rbf
# [CV 4/5; 212/294] END model__C=100, model__class_weight=None, model__gamma=0.001, model__kernel=rbf;, score=0.938 total time=   2.5s
# [CV 5/5; 214/294] START model__C=100, model__class_weight=None, model__gamma=0.01, model__kernel=linear
# [CV 5/5; 214/294] END model__C=100, model__class_weight=None, model__gamma=0.01, model__kernel=linear;, score=0.878 total time=   3.7s
# [CV 1/5; 217/294] START model__C=100, model__class_weight=None, model__gamma=0.1, model__kernel=linear
# [CV 1/5; 217/294] END model__C=100, model__class_weight=None, model__gamma=0.1, model__kernel=linear;, score=0.887 total time=   3.8s
# [CV 3/5; 219/294] START model__C=100, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid
# [CV 3/5; 219/294] END model__C=100, model__class_weight=None, model__gamma=0.1, model__kernel=sigmoid;, score=0.782 total time=   0.9s
# [CV 5/5; 220/294] START model__C=100, model__class_weight=None, model__gamma=1, model__kernel=linear
# [CV 5/5; 220/294] END model__C=100, model__class_weight=None, model__gamma=1, model__kernel=linear;, score=0.878 total time=   3.8s
# [CV 1/5; 223/294] START model__C=100, model__class_weight=None, model__gamma=10, model__kernel=linear
# [CV 1/5; 223/294] END model__C=100, model__class_weight=None, model__gamma=10, model__kernel=linear;, score=0.887 total time=   3.9s
# [CV 5/5; 224/294] START model__C=100, model__class_weight=None, model__gamma=10, model__kernel=rbf
# [CV 5/5; 224/294] END model__C=100, model__class_weight=None, model__gamma=10, model__kernel=rbf;, score=0.890 total time=   6.2s
# [CV 4/5; 227/294] START model__C=100, model__class_weight=None, model__gamma=100, model__kernel=rbf
# [CV 4/5; 227/294] END model__C=100, model__class_weight=None, model__gamma=100, model__kernel=rbf;, score=0.849 total time=   7.2s
# [CV 5/5; 230/294] START model__C=100, model__class_weight=None, model__gamma=1000, model__kernel=rbf
# [CV 5/5; 230/294] END model__C=100, model__class_weight=None, model__gamma=1000, model__kernel=rbf;, score=0.504 total time=   6.1s
# [CV 3/5; 233/294] START model__C=100, model__class_weight=balanced, model__gamma=0.001, model__kernel=rbf
# [CV 3/5; 233/294] END model__C=100, model__class_weight=balanced, model__gamma=0.001, model__kernel=rbf;, score=0.917 total time=   2.6s
# [CV 4/5; 234/294] START model__C=100, model__class_weight=balanced, model__gamma=0.001, model__kernel=sigmoid
# [CV 4/5; 234/294] END model__C=100, model__class_weight=balanced, model__gamma=0.001, model__kernel=sigmoid;, score=0.934 total time=   2.3s
# [CV 2/5; 236/294] START model__C=100, model__class_weight=balanced, model__gamma=0.01, model__kernel=rbf
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Done
# CPU times: user 8.54 s, sys: 3.08 s, total: 11.6 s
# Wall time: 10min 2s
# /Users/hydraze/anaconda3/envs/aa24/lib/python3.12/site-packages/sklearn/svm/_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=25000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(

# %%
svc_gs_results = pd.DataFrame(data=svc_gs_est.cv_results_)
svc_gs_results.sort_values(by='rank_test_score', ascending = True).to_csv('output/svc_gridsearchcv_minmaxScaler.csv')
svc_gs_results.sort_values(by='rank_test_score', ascending = True)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 274       2.513853      0.098000         0.143203        0.006042
# 235       2.147909      0.036442         0.146978        0.005600
# 277       2.696006      0.070889         0.130202        0.005631
# 196       1.954036      0.044049         0.140471        0.007258
# 193       2.358453      0.104560         0.161871        0.005502
# ..             ...           ...              ...             ...
# 140       1.082970      0.018771         0.050431        0.002921
# 98        1.083839      0.014438         0.047162        0.001059
# 200       3.049208      0.076726         0.100799        0.010757
# 242       3.051158      0.066172         0.104288        0.005092
# 284       2.964680      0.054394         0.103719        0.003137
#
#     param_model__C param_model__class_weight param_model__gamma  \
# 274           1000                  balanced              0.001
# 235            100                  balanced               0.01
# 277           1000                  balanced               0.01
# 196             10                  balanced                0.1
# 193             10                  balanced               0.01
# ..             ...                       ...                ...
# 140              1                      None                 10
# 98             0.1                      None                 10
# 200             10                  balanced                  1
# 242            100                  balanced                  1
# 284           1000                  balanced                  1
#
#     param_model__kernel                                             params  \
# 274                 rbf  {'model__C': 1000, 'model__class_weight': 'bal...
# 235                 rbf  {'model__C': 100, 'model__class_weight': 'bala...
# 277                 rbf  {'model__C': 1000, 'model__class_weight': 'bal...
# 196                 rbf  {'model__C': 10, 'model__class_weight': 'balan...
# 193                 rbf  {'model__C': 10, 'model__class_weight': 'balan...
# ..                  ...                                                ...
# 140             sigmoid  {'model__C': 1, 'model__class_weight': None, '...
# 98              sigmoid  {'model__C': 0.1, 'model__class_weight': None,...
# 200             sigmoid  {'model__C': 10, 'model__class_weight': 'balan...
# 242             sigmoid  {'model__C': 100, 'model__class_weight': 'bala...
# 284             sigmoid  {'model__C': 1000, 'model__class_weight': 'bal...
#
#      split0_test_score  split1_test_score  split2_test_score  \
# 274           0.935814           0.927265           0.915172
# 235           0.936572           0.925506           0.911887
# 277           0.938856           0.926984           0.909627
# 196           0.937781           0.927411           0.906965
# 193           0.930159           0.926556           0.914415
# ..                 ...                ...                ...
# 140           0.540875           0.426507           0.491987
# 98            0.534359           0.428028           0.494449
# 200           0.434434           0.460450           0.484549
# 242           0.433164           0.461134           0.470625
# 284           0.433372           0.461110           0.470234
#
#      split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 274           0.943045           0.945597         0.933379        0.011113
# 235           0.938355           0.948569         0.932178        0.012509
# 277           0.936389           0.941606         0.930692        0.011625
# 196           0.939149           0.941752         0.930611        0.012789
# 193           0.939613           0.942297         0.930608        0.009966
# ..                 ...                ...              ...             ...
# 140           0.463290           0.372926         0.459117        0.057052
# 98            0.459577           0.376425         0.458567        0.054245
# 200           0.458667           0.407254         0.449071        0.026242
# 242           0.456884           0.406866         0.445735        0.023021
# 284           0.457055           0.406393         0.445633        0.023088
#
#      rank_test_score
# 274                1
# 235                2
# 277                3
# 196                4
# 193                5
# ..               ...
# 140              290
# 98               291
# 200              292
# 242              293
# 284              294
#
# [294 rows x 17 columns]

# %%
# Best params
svc_gs_est.best_params_
# Out:
# {'model__C': 1000,
#  'model__class_weight': 'balanced',
#  'model__gamma': 0.001,
#  'model__kernel': 'rbf'}

# %%
# Test on test set
"""
Goes up fast, but then struggles to improve TPR without increasing FPR
"""
predicted_probabilities = svc_gs_est.predict_proba(X_test)
auc_score = roc_auc_score(y_test, predicted_probabilities[:, 1])
print(f"AUC Score: {round(auc_score, 3)}") # 0.9265646948649914

RocCurveDisplay.from_estimator(svc_gs_est, X_test, y_test)
# Out:
# AUC Score: 0.927

# %%
# Feature importance: To note, some numerical variables share permutation importance due to high correlation
# Handset, international mins sum and usage band is at the top. As above:

"""
All_calls_mins highly correlated to National minutes. It's a sum of National minutes + International mins maybe. [International and all call mins quite impt]
Nat_call_cost_Sum could be an adjustment of actual call cost, correlation 0.999. [Actual call cost much more important than nat call cost]
Total_call_cost most strongly correlated with International_mins_Sum and Total_Cost [all 3 relatively impt]
Peak_mins_Sum highly correlated with all_calls_mins and national mins [these 3 all low feature importance]

"""
perm_importance = permutation_importance(svc_gs_est, X_test, y_test)

features = svc_gs_est.feature_names_in_

sorted_idx = perm_importance.importances_mean.argsort()
plt.barh(features[sorted_idx], perm_importance.importances_mean[sorted_idx])
plt.xlabel("Permutation Importance")
# Out:
# Text(0.5, 0, 'Permutation Importance')

# %%
# Plotting predicted probabilities against metric avg cost min
# 50% seems to be a clean cut-off
plt.scatter(y=predicted_probabilities[:, 1], x=X_test['average cost min'], alpha=0.6, )
plt.xlabel("average cost min")
plt.ylabel("pred probability")
# Out:
# Text(0, 0.5, 'pred probability')

# %%
# Plotting residuals against metric avg cost min
# Most individuals where the algorithm predicts within a limit of +/-0.5 do not have high average cost per minute.
# The high value customers were "false positives" in a sense, if we were to use a decision boundary of 0.5.
plt.scatter(y=(y_test-predicted_probabilities[:, 1]), x=X_test['average cost min'], alpha=0.6)
plt.xlabel("average cost min")
plt.ylabel("residuals")
# Out:
# Text(0, 0.5, 'residuals')

# %%
# Using 25% as threshold 
pd.crosstab((predicted_probabilities[:, 1]>=0.25).astype(int), y_test)
# Out:
# target    0    1
# row_0
# 0       827   34
# 1        33  115

# %%
# Retrain best model on all train data: Set up the params accordingly
numerical_preprocessor = Pipeline([
    ("scaler", MinMaxScaler())
])

categorical_preprocessor = Pipeline([
    ("onehot", OneHotEncoder(drop="if_binary"))
])

best_svc_model = Pipeline([
    ("preprocessor", ColumnTransformer([
        ("numerical", numerical_preprocessor, NUM_VARS),
        ("categorical", categorical_preprocessor, CAT_VARS)
    ])),
    ("model", SVC(probability=True, random_state=SEED, C=1000, gamma=0.001, class_weight='balanced', kernel="rbf"))
])

best_svc_model.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('scaler',
#                                                                    MinMaxScaler())]),
#                                                   Index(['Age', 'L_O_S', 'Dropped_Calls', 'Peak_calls_Sum', 'Peak_mins_Sum',
#        'OffPeak_calls_Sum', 'OffPeak_mins_Sum', 'Weekend_calls_Sum',
#        'Weekend_mins_Sum', 'International_mins_Sum', 'Nat_call_cost_Sum',
#        'AvePeak', 'AveOffPeak', 'AveWeekend',...
#        'Total_call_cost', 'Total_Cost', 'average cost min', 'Peak ratio',
#        'OffPeak ratio', 'Weekend ratio', 'Nat-InterNat Ratio'],
#       dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(drop='if_binary'))]),
#                                                   Index(['Gender', 'tariff', 'Handset', 'Usage_Band', 'Tariff_OK',
#        'high Dropped calls', 'No Usage'],
#       dtype='object'))])),
#                 ('model',
#                  SVC(C=1000, class_weight='balanced', gamma=0.001,
#                      probability=True, random_state=42))])

# %%
# For submission
test_data_sub = pd.DataFrame(data={'ID':test_data['id'], 
                                   'PRED':best_svc_model.predict_proba(test_data)[:,1]})
test_data_sub.to_csv('output/svc_submission.csv', header=True, index=False)

# %%
# For submission: Adjust for those cases with high average cost min
test_data_sub_adjusted = pd.DataFrame(data={'ID':test_data['id'], 
                                   'PRED':best_svc_model.predict_proba(test_data)[:,1],
                                           'average cost min':test_data['average cost min']})
test_data_sub_adjusted.plot(y="PRED", x="average cost min", kind="scatter")
test_data_sub_adjusted['quantile'] = (pd.qcut(test_data_sub_adjusted["average cost min"].values, 10,labels=False) + 1) / 10
test_data_sub_adjusted['PRED'] = test_data_sub_adjusted['PRED'] * test_data_sub_adjusted['quantile']
test_data_sub_adjusted['PRED'].describe()
test_data_sub.to_csv('output/svc_submission_adjusted1.csv', header=True, index=False)

# %%
# For submission: use prediction threshold of 25%.  
test_data_sub_hardadjusted = pd.DataFrame(data={'ID':test_data['id'], 
                                   'PRED':best_svc_model.predict_proba(test_data)[:,1]})
test_data_sub_hardadjusted['PRED'] = (test_data_sub_hardadjusted['PRED'] >=0.25).astype(int)
test_data_sub_hardadjusted.to_csv('output/svc_submission_hardadjusted.csv', header=True, index=False)

# %%
# For submission: use prediction threshold of 25%. Sort values by average cost min 
test_data_sub_hardadjusted_sorted = pd.DataFrame(data={'ID':test_data['id'], 
                                   'PRED':best_svc_model.predict_proba(test_data)[:,1],
                                           'average cost min':test_data['average cost min']})
test_data_sub_hardadjusted_sorted['PRED'] = (test_data_sub_hardadjusted_sorted['PRED'] >=0.25).astype(int)
test_data_sub_hardadjusted_sorted = test_data_sub_hardadjusted_sorted.sort_values(by=['PRED', 'average cost min'], ascending=False)
test_data_sub_hardadjusted_sorted = test_data_sub_hardadjusted_sorted.drop(columns=['average cost min'])
test_data_sub_hardadjusted_sorted.to_csv('output/svc_submission_hardadjusted_sorted.csv', header=True, index=False)

# %%
# For submission: use prediction threshold of 25% + adjust for cases with high average cosst min. 
test_data_sub_adjusted2 = pd.DataFrame(data={'ID':test_data['id'], 
                                   'PRED':best_svc_model.predict_proba(test_data)[:,1],
                                           'average cost min':test_data['average cost min']})
test_data_sub_adjusted2['PRED'] = (test_data_sub_adjusted2['PRED'] >=0.25).astype(int)
test_data_sub_adjusted2['quantile'] = (pd.qcut(test_data_sub_adjusted2["average cost min"].values, 10,labels=False) + 1) / 10
test_data_sub_adjusted2['PRED'] = test_data_sub_adjusted2['PRED'] * test_data_sub_adjusted2['quantile'] 

test_data_sub_adjusted2.plot(x="quantile", y="PRED", kind="scatter")
test_data_sub_adjusted2 = test_data_sub_adjusted2.drop(columns=['quantile', 'average cost min'])
test_data_sub_adjusted2.to_csv('output/svc_submission_adjusted2.csv', header=True, index=False)

# %% [markdown]
# **XGBoost**

# %%
# Basic preprocessing
numeric_transformer = Pipeline(
    steps = [
        ("imputer", SimpleImputer(strategy="median"))
    ]
)

categorical_transformer = Pipeline(
    steps = [
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("encoder", OneHotEncoder())
    ]
)

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, NUM_VARS),
        ("cat", categorical_transformer, CAT_VARS)
    ]
)

X_preprocessed = preprocessor.fit_transform(X)
# Alternatively split train-test before, do preprocessing on training data (fit_transform) then transform test data

# %%
X_train, X_test, y_train, y_test= train_test_split(X_preprocessed, y, test_size=0.2, stratify=y, random_state=420)

# %% [markdown]
# Grid search

# %%
# Calcualte class ratio. Will be used to assess class imbalance during training
ratio = float(y_train.value_counts()[0]) / y_train.value_counts()[1]

# %%
# First do a random search over a large hyperparameter space, trying 1000 random models 
gbm_param_grid_large = {  'n_estimators': np.arange(5, 101, 1)
                        , 'max_depth': range(2, 13)
                        , 'learning_rate': np.arange(0.001, 5, 0.01)
                        , 'subsample': [0.2, 0.4, 0.6, 0.8, 1]
                        , 'colsample_bytree': [0.2, 0.5, 0.8, 1]
                        , 'reg_lambda': [0, 1, 5, 10, 100]
                        }

gbm = xgb.XGBClassifier(random_state=420, scale_pos_weight=ratio)
randomized_auc = RandomizedSearchCV(  estimator=gbm
                                    , param_distributions=gbm_param_grid_large
                                    , n_iter=1000
                                    , scoring='roc_auc'
                                    , cv=5
                                    , n_jobs=-1
                                    , verbose=1
                                    , random_state=420)

# See how the cross-validation performed (on the "training" data) and the best tuned hyperparameter values
randomized_auc.fit(X_train, y_train)
print("Best parameters found: ",randomized_auc.best_params_)
print("Lowest AUC found: ", randomized_auc.best_score_)

# %%
# Now do another random search over a smaller hyperparameter space around the preivously found "best" values
gbm_param_grid_medium = {  'n_estimators': np.arange(50, 120, 1)
                         , 'max_depth': range(6, 15)
                         , 'learning_rate': np.arange(0.001, 5, 0.01)
                         , 'subsample': [0.6, 0.8, 1]
                         , 'colsample_bytree': [0.8, 1]
                         , 'reg_lambda': [0, 1, 2, 5]
                         }

gbm = xgb.XGBClassifier(random_state=420, scale_pos_weight=ratio)
randomized_auc = RandomizedSearchCV(  estimator=gbm
                                    , param_distributions=gbm_param_grid_medium
                                    , n_iter=1000
                                    , scoring='roc_auc'
                                    , cv=5
                                    , n_jobs=-1
                                    , verbose=1
                                    , random_state=420)

# See how the cross-validation performed (on the "training" data) and the best tuned hyperparameter values
randomized_auc.fit(X_train, y_train)
print("Best parameters found: ",randomized_auc.best_params_)
print("Lowest AUC found: ", randomized_auc.best_score_)

# %%
# We got quite different reults, but different hyperparameter combinations can give similar results.
# Finally a grid-search that is not random around the previous "best" values.
gbm_param_grid = {  'n_estimators': [70, 80, 100, 120]
                  , 'max_depth': [8, 10, 12]
                  , 'learning_rate': [0.05, 0.1, 0.15, 0.2]
                  , 'subsample': [0.8, 1]
                  , 'colsample_bytree': [0.8, 1]
                  , 'reg_lambda': [0, 1, 2]
                  }

gbm = xgb.XGBClassifier(random_state=420, scale_pos_weight=ratio)
grid_auc = GridSearchCV(  estimator=gbm
                        , param_grid=gbm_param_grid
                        , scoring='roc_auc'
                        , cv=5
                        , n_jobs=-1
                        , verbose=1
                        )

# See how the cross-validation performed (on the "training" data) and the best tuned hyperparameter values
grid_auc.fit(X_train, y_train)
print("Best parameters found: ", grid_auc.best_params_)
print("Lowest AUC found: ", grid_auc.best_score_)

# %%
# Save an output based on the previous (last) grid search
pd.DataFrame(grid_auc.cv_results_).sort_values(by='rank_test_score', ascending = True).to_csv('output/xgb_gridsearch.csv')

# %%
# Get an idea about how the model performs on the test set
# Test AUC is close to the "best" model AUC on the cross-validated training set which is a good indication of not suffering from overfitting
predicted_probabilities = grid_auc.predict_proba(X_test)
auc_score = roc_auc_score(y_test, predicted_probabilities[:, 1])
auc_score

# %%
# Re-train the tuned model on the entire training data (not just on the 80% of it)
best_model_xgb = Pipeline([
    ("preprocessor", ColumnTransformer(
        transformers=[
            ("num", numeric_transformer, NUM_VARS),
            ("cat", categorical_transformer, CAT_VARS)
            ]
    )),
    ("xgboost model", grid_auc.best_estimator_)
])


best_model_xgb.fit(X, y)
pred_xgb = pd.DataFrame(best_model_xgb.predict_proba(test_data), columns=["0", "1"])

# Creating data for submission
test_data_sub = pd.DataFrame(data={'ID':test_data['id'], 
                                   'PRED':pred_xgb["1"]})
test_data_sub

# %%
# Exporting results
test_data_sub.to_csv('output/xgboost_pred_submission_v2.csv', header=True, index=False)

# %% [markdown]
# Test - sample weights based on average cost min (?)

# %%
# First do a random search over a large hyperparameter space, trying 1000 random models 
gbm_param_grid_large = {  'n_estimators': np.arange(5, 101, 1)
                        , 'max_depth': range(2, 13)
                        , 'learning_rate': np.arange(0.001, 5, 0.01)
                        , 'subsample': [0.2, 0.4, 0.6, 0.8, 1]
                        , 'colsample_bytree': [0.2, 0.5, 0.8, 1]
                        , 'reg_lambda': [0, 1, 5, 10, 100]
                        }

gbm = xgb.XGBClassifier(random_state=420, scale_pos_weight=ratio)
randomized_auc = RandomizedSearchCV(  estimator=gbm
                                    , param_distributions=gbm_param_grid_large
                                    , n_iter=1000
                                    , scoring='roc_auc'
                                    , cv=5
                                    , n_jobs=-1
                                    , verbose=1
                                    , random_state=420)

# See how the cross-validation performed (on the "training" data) and the best tuned hyperparameter values
randomized_auc.fit(X_train, y_train, sample_weight=X_train[:,24])
print("Best parameters found: ",randomized_auc.best_params_)
print("Lowest AUC found: ", randomized_auc.best_score_)

# %%
# Now do another random search over a smaller hyperparameter space around the preivously found "best" values
gbm_param_grid_large = {  'n_estimators': np.arange(20, 60, 1)
                        , 'max_depth': range(5, 11)
                        , 'learning_rate': np.arange(0.05, 5.05, 0.05)
                        , 'subsample': [0.6, 0.8, 1]
                        , 'colsample_bytree': [0.6, 0.8, 1]
                        , 'reg_lambda': [0, 1, 5, 10]
                        }

gbm = xgb.XGBClassifier(random_state=420, scale_pos_weight=ratio)
randomized_auc = RandomizedSearchCV(  estimator=gbm
                                    , param_distributions=gbm_param_grid_large
                                    , n_iter=1000
                                    , scoring='roc_auc'
                                    , cv=5
                                    , n_jobs=-1
                                    , verbose=1
                                    , random_state=420)

# See how the cross-validation performed (on the "training" data) and the best tuned hyperparameter values
randomized_auc.fit(X_train, y_train, sample_weight=X_train[:,24])
print("Best parameters found: ",randomized_auc.best_params_)
print("Lowest AUC found: ", randomized_auc.best_score_)

# %%
# Finally a grid-search that is not random around the previous "best" values.
gbm_param_grid = {  'n_estimators': [30, 50, 100]
                  , 'max_depth': [8, 10, 12]
                  , 'learning_rate': [0.01, 0.05, 0.1, 0.2]
                  , 'subsample': [0.8, 1]
                  , 'colsample_bytree': [0.8, 1]
                  , 'reg_lambda': [0, 1, 2]
                  }

gbm = xgb.XGBClassifier(random_state=420, scale_pos_weight=ratio)
grid_auc = GridSearchCV(  estimator=gbm
                        , param_grid=gbm_param_grid
                        , scoring='roc_auc'
                        , cv=5
                        , n_jobs=-1
                        , verbose=1
                        )

# See how the cross-validation performed (on the "training" data) and the best tuned hyperparameter values
grid_auc.fit(X_train, y_train, sample_weight=X_train[:,24])
print("Best parameters found: ", grid_auc.best_params_)
print("Lowest AUC found: ", grid_auc.best_score_)

# %%
# Save an output based on the previous (last) grid search
pd.DataFrame(grid_auc.cv_results_).sort_values(by='rank_test_score', ascending = True).to_csv('output/xgb_gridsearch_weighted.csv')

# %%
# Get an idea about how the model performs on the test set
# Test AUC is close to the "best" model AUC on the cross-validated training set which is a good indication of not suffering from overfitting
predicted_probabilities = grid_auc.predict_proba(X_test)
auc_score = roc_auc_score(y_test, predicted_probabilities[:, 1])
auc_score

# %%
# Re-train the tuned model on the entire training data (not just on the 80% of it)
best_model_xgb = Pipeline([
    ("preprocessor", ColumnTransformer(
        transformers=[
            ("num", numeric_transformer, NUM_VARS),
            ("cat", categorical_transformer, CAT_VARS)
            ]
    )),
    ("xgboost_model", grid_auc.best_estimator_)
])


best_model_xgb.fit(X, y) # , xgboost_model__sample_weight=np.array(X['average cost min'])
pred_xgb = pd.DataFrame(best_model_xgb.predict_proba(test_data), columns=["0", "1"])

# Creating data for submission
test_data_sub = pd.DataFrame(data={'ID':test_data['id'], 
                                   'PRED':pred_xgb["1"]})
test_data_sub

# %%
# Exporting results
test_data_sub.to_csv('output/xgboost_pred_submission_v3_weighted.csv', header=True, index=False)
